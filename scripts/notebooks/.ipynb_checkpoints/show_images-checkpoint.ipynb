# %%
cd ../..
# Out:
# /data/projects/windturbine-identification/MachineLearningCourse

# %%
import imp
import scripts.windturbines.functions_pattern_recognition as fpr
imp.reload(fpr)
from IPython.display import Image
import os

# %%
COUNTRY = "CN"

raw_dir = fpr.get_param(COUNTRY, "PATH_RAW_IMAGES_ASSESSMENT") + "turbines"


files = [f.path for f in os.scandir(raw_dir) if not f.is_dir() ]   

cnt = 0

for f in files[1:10]:
    print(cnt)
    print(f)
    display(Image(filename=f) )
    cnt = cnt + 1
# Out:
# 0
# data/aerialImages/GOOGLE/RESOLUTION19/CN/assessment/turbines/118.4228_32.66_0.8637359738349915_Anhui Laian Baoshan Wind.png
# 1
# data/aerialImages/GOOGLE/RESOLUTION19/CN/assessment/turbines/118.4228_32.6782_1.0_Anhui Laian Baoshan Wind.png
# 2
# data/aerialImages/GOOGLE/RESOLUTION19/CN/assessment/turbines/118.4228_32.681_0.9974314570426941_Anhui Laian Baoshan Wind.png
# 3
# data/aerialImages/GOOGLE/RESOLUTION19/CN/assessment/turbines/118.4242_32.6628_0.9605138301849364_Anhui Laian Baoshan Wind.png
# 4
# data/aerialImages/GOOGLE/RESOLUTION19/CN/assessment/turbines/118.4242_32.6698_1.0_Anhui Laian Baoshan Wind.png
# 5
# data/aerialImages/GOOGLE/RESOLUTION19/CN/assessment/turbines/118.4242_32.6754_0.9998290538787842_Anhui Laian Baoshan Wind.png
# 6
# data/aerialImages/GOOGLE/RESOLUTION19/CN/assessment/turbines/118.4242_32.6768_1.0_Anhui Laian Baoshan Wind.png
# 7
# data/aerialImages/GOOGLE/RESOLUTION19/CN/assessment/turbines/118.4242_32.681_0.9997860789299012_Anhui Laian Baoshan Wind.png
# 8
# data/aerialImages/GOOGLE/RESOLUTION19/CN/assessment/turbines/118.4256_32.6614_0.7872654795646667_Anhui Laian Baoshan Wind.png
