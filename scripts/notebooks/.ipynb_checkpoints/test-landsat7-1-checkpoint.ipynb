# %%
cd /data/projects/windturbine-identification/MachineLearningCourse
# Out:
# /data/projects/windturbine-identification/MachineLearningCourse

# %%
import ee
from pathlib import Path
import os
import pandas as pd
import numpy as np
import folium

ee.Initialize()


def read_params():
    
    config_file = "config"
    
    
    files = [x for x in os.listdir(config_file) if (x.endswith(".csv") and x.startswith("params"))]
    p = {}
    
    countries = []
    
    for i in files:
        country = i[6:-4]
        countries.append(country)
        
        p[country] = pd.read_csv(config_file + "/" + i)
    
    return((countries,p))
        
COUNTRIES, PARAMS = read_params()


def get_param(country,name):
    val=PARAMS[country].at[0,name]
    return(val)

COUNTRY = 'AT'

turbines = pd.read_csv(get_param(COUNTRY, "FILE_TURBINE_LOCATIONS"))

turbines.head()
# Test the earthengine command by getting help on upload.
#!earthengine upload image -h

#%config IPCompleter.greedy=True
# Out:
#                          Name          Betreiber1 Betreiber2  n_Anlagen  \
# 0      Wagram/Donau,_Anlage 1                   -        ---          1
# 1      St._Pölten I, Anlage 1                   -        ---          1
# 2        Michelbach,_Anlage 1  WEB Windenergie AG        ---          1
# 3  Groissenbrunn_II, Anlage 1                   -        ---          1
# 4            Laussa,_Anlage 1                   -        ---          3
#
#       KW   Type    Jahr        Lat       Long                 url Hersteller  \
# 0  150.0    N27  1994.0  48.159961  16.735460                   -     Nordex
# 1  110.0     20  1994.0  48.222287  15.623049                   -    Seewind
# 2  225.0    V29  1995.0  48.085344  15.757397  www.windenergie.at     Vestas
# 3  250.0    N29  1996.0  48.235437  16.901598                   -     Nordex
# 4  600.0  TW600  1996.0  47.952050  14.493740                   -      Tacke
#
#    Nabenhoehe  Rotordurchmesser                   Name_Save              Park
# 0        36.0              27.0      Wagram/Donau, Anlage 1       WagramDonau
# 1        31.0              20.0      St. Pölten I, Anlage 1      St._Pölten I
# 2        31.0              29.0        Michelbach, Anlage 1        Michelbach
# 3        50.0              30.0  Groissenbrunn II, Anlage 1  Groissenbrunn_II
# 4        50.0              43.0            Laussa, Anlage 1            Laussa

# %%
bands = ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7']
#bands = ['B2', 'B3', 'B4']
# Use Landsat 8 surface reflectance data.
l8sr = ee.ImageCollection("LANDSAT/LE07/C01/T1_SR")

# Cloud masking function.
def maskL8sr(image):
  cloudShadowBitMask = ee.Number(2).pow(3).int()
  cloudsBitMask = ee.Number(2).pow(5).int()
  qa = image.select('pixel_qa')
  mask = qa.bitwiseAnd(cloudShadowBitMask).eq(0).And(
    qa.bitwiseAnd(cloudsBitMask).eq(0))
  return image.updateMask(mask).select(bands).divide(10000)

# The image input data is a 2018 cloud-masked median composite.
reducer = ee.Reducer.median()

reducer_str = "median"

years = range(2000, 2019)

images = []

for year in years:
    image = l8sr.filterDate(str(year) + '-06-01', str(year) + '-09-30').map(maskL8sr).reduce(reducer)
    images.append(image)

# %%
def one_turbine(x, y, images, name):
    vals = np.zeros(len(range(0, 19)))

    for i in range(0, 19):
        #print(i)
        image_final = images[i]

        offset = 0.0005
        
        p = ee.Geometry.Rectangle(x - offset, y - offset, x + offset, y + offset)
#        p = ee.Geometry.Point(x, y)

        # Extract the data
        data = image_final.select(name).reduceRegion(ee.Reducer.max(), p, 30).get(name)

        # Convert to Number for further use
        dataN = ee.Number(data)

        d = dataN.getInfo()

        vals[i] = d
        
        
    max_year = np.where(max(vals) == vals)[0][0]    
    
        
    return((max_year + 2000, vals))

# %%
n = turbines.shape[0]
results = np.zeros((n, 2))

idx = turbines['Jahr'] > 2002

turbines = turbines[idx]

turbines.head()
# Out:
#                    Name                         Betreiber1 Betreiber2  \
# 107  Neusiedl,_Anlage 1  Energie Burgenland Windkraft GmbH        ---
# 108  Neusiedl,_Anlage 2  Energie Burgenland Windkraft GmbH        ---
# 109  Neusiedl,_Anlage 3  Energie Burgenland Windkraft GmbH        ---
# 110  Neusiedl,_Anlage 4  Energie Burgenland Windkraft GmbH        ---
# 111  Neusiedl,_Anlage 5  Energie Burgenland Windkraft GmbH        ---
#
#      n_Anlagen      KW       Type    Jahr        Lat       Long  \
# 107         18  1800.0  E66 18.70  2003.0  47.959017  16.883703
# 108         18  1800.0  E66 18.70  2003.0  47.956774  16.903812
# 109         18  1800.0  E66 18.70  2003.0  47.957868  16.909858
# 110         18  1800.0  E66 18.70  2003.0  47.961487  16.903751
# 111         18  1800.0  E66 18.70  2003.0  47.953002  16.890762
#
#                           url Hersteller  Nabenhoehe  Rotordurchmesser  \
# 107  www.energieburgenland.at    Enercon        86.0              70.0
# 108  www.energieburgenland.at    Enercon        86.0              70.0
# 109  www.energieburgenland.at    Enercon        86.0              70.0
# 110  www.energieburgenland.at    Enercon        86.0              70.0
# 111  www.energieburgenland.at    Enercon        86.0              70.0
#
#               Name_Save      Park
# 107  Neusiedl, Anlage 1  Neusiedl
# 108  Neusiedl, Anlage 2  Neusiedl
# 109  Neusiedl, Anlage 3  Neusiedl
# 110  Neusiedl, Anlage 4  Neusiedl
# 111  Neusiedl, Anlage 5  Neusiedl

# %%
from time import time

all_results = []

start_time_all = time()

for index, row in turbines.iterrows():
    start_time = time()
    print("Turbine assessment of " + row['Name'])
    year_estimated, vals = one_turbine(row['Long'], row['Lat'], images, "B2_median")
    all_results.append(vals)
    year_real = row['Jahr']
    print(year_estimated)
    print(year_real)
    print(vals)
    print(row['Long'])
    print(row['Lat'])
    results[index, 0] = year_estimated
    results[index, 1] = year_real
    end_time = time()
    print("One turbine took " + str(end_time - start_time) + " seconds")
    #one_turbine(x, y, images)

end_time_all = time()
print("All took " + str(end_time_all - start_time_all) + " seconds")
# Out:
# Turbine assessment of Neusiedl,_Anlage 1
# 2013
# 2003.0
# [0.18359999 0.14579999 0.1419     0.1824     0.1725     0.13169999
#  0.1496     0.1513     0.1585     0.1496     0.18000001 0.1706
#  0.1802     0.2018     0.1929     0.19220001 0.1618     0.1762
#  0.16769999]
# 16.883703
# 47.959016999999996
# One turbine took 9.969661235809326 seconds
# Turbine assessment of Neusiedl,_Anlage 2
# 2013
# 2003.0
# [0.15530001 0.1296     0.1233     0.15360001 0.1442     0.13249999
#  0.16005    0.1274     0.13240001 0.12620001 0.1231     0.12025
#  0.13105001 0.197      0.15189999 0.11965    0.13275    0.119
#  0.1214    ]
# 16.903812
# 47.956773999999996
# One turbine took 9.080877542495728 seconds
# Turbine assessment of Neusiedl,_Anlage 3
# 2013
# 2003.0
# [0.15530001 0.1208     0.1188     0.1494     0.14210001 0.13249999
#  0.16005    0.1274     0.12909999 0.12620001 0.1189     0.1293
#  0.13105001 0.1807     0.13860001 0.11965    0.1156     0.1214
#  0.1082    ]
# 16.909858
# 47.957868
# One turbine took 12.669409990310669 seconds
# Turbine assessment of Neusiedl,_Anlage 4
# 2014
# 2003.0
# [0.1981     0.19050001 0.17165001 0.1865     0.17749999 0.17919999
#  0.1891     0.1521     0.18835001 0.17745    0.2005     0.16554999
#  0.18425    0.18189999 0.2156     0.18115    0.1409     0.14055
#  0.1568    ]
# 16.903751
# 47.961487
# One turbine took 11.742308855056763 seconds
# Turbine assessment of Neusiedl,_Anlage 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-84-c1efa30b5675> in <module>
#       8     start_time = time()
#       9     print("Turbine assessment of " + row['Name'])
# ---> 10     year_estimated, vals = one_turbine(row['Long'], row['Lat'], images, "B2_median")
#      11     all_results.append(vals)
#      12     year_real = row['Jahr']
#
# <ipython-input-82-751b2f7e4a58> in one_turbine(x, y, images, name)
#      15         dataN = ee.Number(data)
#      16
# ---> 17         d = dataN.getInfo()
#      18
#      19         vals[i] = d
#
# ~/.conda/envs/google-earth-engine/lib/python3.7/site-packages/ee/computedobject.py in getInfo(self)
#      93       The object can evaluate to anything.
#      94     """
# ---> 95     return data.computeValue(self)
#      96
#      97   def encode(self, encoder):
#
# ~/.conda/envs/google-earth-engine/lib/python3.7/site-packages/ee/data.py in computeValue(obj)
#     621         project=_get_projects_path(),
#     622         prettyPrint=False))['result']
# --> 623   return send_('/value', ({'json': obj.serialize(), 'json_format': 'v2'}))
#     624
#     625
#
# ~/.conda/envs/google-earth-engine/lib/python3.7/site-packages/ee/data.py in send_(path, params, opt_method, opt_raw)
#    1642     return response, content
#    1643
# -> 1644   response, content = send_with_backoff()
#    1645
#    1646   # Call the profile hook if present. Note that this is done before we handle
#
# ~/.conda/envs/google-earth-engine/lib/python3.7/site-packages/ee/data.py in send_with_backoff(retries)
#    1633     try:
#    1634       response, content = http.request(
# -> 1635           url, method=opt_method, body=payload, headers=headers)
#    1636       if response.status == 429:
#    1637         if retries < MAX_RETRIES:
#
# ~/.conda/envs/google-earth-engine/lib/python3.7/site-packages/google_auth_httplib2.py in request(self, uri, method, body, headers, **kwargs)
#     196         # Make the request.
#     197         response, content = self.http.request(
# --> 198             uri, method, body=body, headers=request_headers, **kwargs)
#     199
#     200         # If the response indicated that the credentials needed to be
#
# ~/.conda/envs/google-earth-engine/lib/python3.7/site-packages/httplib2/__init__.py in request(self, uri, method, body, headers, redirections, connection_type)
#    1951                         headers,
#    1952                         redirections,
# -> 1953                         cachekey,
#    1954                     )
#    1955         except Exception as e:
#
# ~/.conda/envs/google-earth-engine/lib/python3.7/site-packages/httplib2/__init__.py in _request(self, conn, host, absolute_uri, request_uri, method, body, headers, redirections, cachekey)
#    1616
#    1617         (response, content) = self._conn_request(
# -> 1618             conn, request_uri, method, body, headers
#    1619         )
#    1620
#
# ~/.conda/envs/google-earth-engine/lib/python3.7/site-packages/httplib2/__init__.py in _conn_request(self, conn, request_uri, method, body, headers)
#    1522             try:
#    1523                 if conn.sock is None:
# -> 1524                     conn.connect()
#    1525                 conn.request(method, request_uri, body, headers)
#    1526             except socket.timeout:
#
# ~/.conda/envs/google-earth-engine/lib/python3.7/site-packages/httplib2/__init__.py in connect(self)
#    1305                 sock.connect((self.host, self.port))
#    1306
# -> 1307                 self.sock = self._context.wrap_socket(sock, server_hostname=self.host)
#    1308
#    1309                 # Python 3.3 compatibility: emulate the check_hostname behavior
#
# ~/.conda/envs/google-earth-engine/lib/python3.7/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     410             server_hostname=server_hostname,
#     411             context=self,
# --> 412             session=session
#     413         )
#     414
#
# ~/.conda/envs/google-earth-engine/lib/python3.7/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#     851                         # non-blocking
#     852                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 853                     self.do_handshake()
#     854             except (OSError, ValueError):
#     855                 self.close()
#
# ~/.conda/envs/google-earth-engine/lib/python3.7/ssl.py in do_handshake(self, block)
#    1115             if timeout == 0.0 and block:
#    1116                 self.settimeout(None)
# -> 1117             self._sslobj.do_handshake()
#    1118         finally:
#    1119             self.settimeout(timeout)
#
# KeyboardInterrupt:
