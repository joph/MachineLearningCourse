# %%
cd /data/projects/windturbine-identification/MachineLearningCourse
# Out:
# /data/projects/windturbine-identification/MachineLearningCourse

# %%
"""
Created on Mon Feb 18 20:30:48 2019

@author: jschmidt
"""

import os, shutil, random

import pandas as pd
import sys
import gdal
import imp
import numpy as np


import scripts.windturbines.functions_pattern_recognition as fpr
imp.reload(fpr)
from scripts.windturbines.functions_pattern_recognition import get_param
from scripts.windturbines.functions_pattern_recognition import cop_predict
from scripts.windturbines.functions_pattern_recognition import check_image
from scripts.windturbines.functions_pattern_recognition import read_params
# Out:
# Using TensorFlow backend.

# %%
COUNTRY = "US"

train_dir = get_param(COUNTRY,"PATH_ML_IMAGES_TYPE_REGRESSION_TRAIN")
test_dir = get_param(COUNTRY,"PATH_ML_IMAGES_TYPE_REGRESSION_TEST")

#### delete directories if exist
#### create if not exist

shutil.rmtree(train_dir,ignore_errors=True)
shutil.rmtree(test_dir,ignore_errors=True)

os.makedirs(train_dir)
os.makedirs(test_dir)

src_dir_tb = get_param(COUNTRY,"PATH_RAW_IMAGES_TURBINES")

# %%
turbines_us = pd.read_csv(get_param("US","FILE_TURBINE_LOCATIONS"))

predictions_cs = get_param("US",
                            "PATH_RAW_IMAGES_TURBINES")

turbines_pred = pd.read_feather(predictions_cs + "all_predictions.feather")

turbines_us['prediction'] = turbines_pred['prediction']
turbines_us['filenames'] = turbines_pred['filenames']

turbines_us['id'] = np.arange(1, turbines_us.shape[0] + 1)
turbines_us.shape

turbines_us = turbines_us[turbines_pred['prediction'] > 0.99]

# %%
turbines_pred[turbines_pred['prediction'] < 0.99]
# Out:
#              Long        Lat  prediction  filenames directory country
# 0     -118.270027  35.066048    0.613175      1.tif                US
# 1     -118.237885  35.263294    0.813057      2.tif                US
# 3     -118.228088  35.200497    0.010981      4.tif                US
# 6     -118.354889  35.085094    0.008799      7.tif                US
# 7     -100.710289  32.454193    0.055050      8.tif                US
# 8     -118.354425  35.083283    0.038192      9.tif                US
# 9     -116.652934  33.954193    0.010791     10.tif                US
# 10    -116.572586  33.889496    0.679927     11.tif                US
# 11    -162.661880  60.336800    0.001568     12.tif                US
# 15    -116.658089  33.958694    0.291744     16.tif                US
# 16    -116.562088  33.899296    0.001808     17.tif                US
# 18    -116.659988  33.960396    0.383128     19.tif                US
# 20    -118.388084  35.057796    0.983504     21.tif                US
# 21    -116.576166  33.897630    0.805910     22.tif                US
# 27    -118.244888  35.274593    0.323688     28.tif                US
# 28    -118.370135  35.073589    0.627844     29.tif                US
# 31    -118.386048  35.061490    0.312253     32.tif                US
# 34    -118.296323  35.080979    0.227238     35.tif                US
# 35    -118.389008  35.063926    0.916127     36.tif                US
# 36    -116.569191  33.891396    0.376101     37.tif                US
# 39    -116.660977  33.940204    0.014534     40.tif                US
# 43    -116.661125  33.940679    0.012472     44.tif                US
# 44    -116.575089  33.890797    0.834486     45.tif                US
# 45    -116.660757  33.942960    0.489139     46.tif                US
# 47    -116.570885  33.890495    0.577134     48.tif                US
# 48    -118.293280  35.108821    0.358772     49.tif                US
# 50    -116.660230  33.958408    0.012312     51.tif                US
# 51    -118.345291  35.062695    0.432043     52.tif                US
# 56    -116.658287  33.958897    0.178135     57.tif                US
# 57    -116.579185  33.891994    0.966003     58.tif                US
# ...           ...        ...         ...        ...       ...     ...
# 59850  -99.245277  34.079346    0.001856  59851.tif                US
# 59851 -101.104439  31.323225    0.002840  59852.tif                US
# 59852  -97.313324  42.320457    0.004268  59853.tif                US
# 59853 -101.160104  31.246891    0.005113  59854.tif                US
# 59854  -97.609253  27.604477    0.011844  59855.tif                US
# 59856  -97.791359  28.171064    0.018785  59857.tif                US
# 59858 -101.108940  31.278522    0.002497  59859.tif                US
# 59859 -103.183312  34.761616    0.002335  59860.tif                US
# 59860 -101.226036  39.319996    0.014573  59861.tif                US
# 59861 -103.185005  34.795193    0.000884  59862.tif                US
# 59862 -101.117806  31.280148    0.004104  59863.tif                US
# 59863  -99.275116  34.072330    0.003643  59864.tif                US
# 59864 -101.107361  31.290703    0.034332  59865.tif                US
# 59865  -95.357071  43.275497    0.006458  59866.tif                US
# 59866  -84.690620  43.418530    0.000912  59867.tif                US
# 59869 -101.573495  33.942025    0.611001  59870.tif                US
# 59870 -101.572980  33.966478    0.049477  59871.tif                US
# 59871 -101.577076  33.960513    0.025797  59872.tif                US
# 59872 -101.568502  33.965937    0.088987  59873.tif                US
# 59873 -101.581989  33.949245    0.052090  59874.tif                US
# 59874 -101.569166  33.942267    0.011326  59875.tif                US
# 59875 -101.568340  33.950867    0.008037  59876.tif                US
# 59876 -101.582609  33.958905    0.017042  59877.tif                US
# 59877 -101.586325  33.948665    0.033039  59878.tif                US
# 59878 -101.602853  33.974889    0.060015  59879.tif                US
# 59879 -101.633138  33.924580    0.015701  59880.tif                US
# 59880 -101.585992  33.965336    0.013310  59881.tif                US
# 59881 -101.572858  33.951399    0.039845  59882.tif                US
# 59882 -101.606528  33.942986    0.059946  59883.tif                US
# 59883 -118.342384  35.092495    0.967836  59884.tif                US
#
# [12219 rows x 6 columns]

# %%
turbines_us.shape
# Out:
# (47665, 30)

# %%
nmb_samples_all = turbines_us.shape[0]

#turbines_us = turbines_us[turbines_us['id'] <= nmb_samples_all]
#turbines_us.shape

# %%
share_train = nmb_samples_all * 0.8
share_train

turbines_us
# Out:
#        case_id    faa_ors            faa_asn  usgs_pr_id t_state  \
# 2      3000003        NaN                NaN      3100.0      CA
# 4      3000008        NaN                NaN      3463.0      CA
# 5      3000010        NaN                NaN     16102.0      CA
# 12     3000025        NaN                NaN     12159.0      CA
# 13     3000026        NaN                NaN      6696.0      CA
# 14     3000034        NaN                NaN      5183.0      CA
# 17     3000053        NaN                NaN      6912.0      CA
# 19     3000059        NaN                NaN      5935.0      CA
# 22     3000073        NaN                NaN      4329.0      CA
# 23     3000075        NaN                NaN      2744.0      CA
# 24     3000076        NaN                NaN      3819.0      CA
# 25     3000078        NaN                NaN      3846.0      CA
# 26     3000081        NaN                NaN      5908.0      CA
# 29     3000086        NaN                NaN     15221.0      CA
# 30     3000088        NaN                NaN     11050.0      CA
# 32     3000090        NaN                NaN     11091.0      CA
# 33     3000094        NaN                NaN      3942.0      CA
# 37     3000100        NaN                NaN      3832.0      CA
# 38     3000102        NaN                NaN     20799.0      IA
# 40     3000109        NaN                NaN      4075.0      CA
# 41     3000110        NaN                NaN     14352.0      CA
# 42     3000112        NaN                NaN      3213.0      CA
# 46     3000122        NaN                NaN      6949.0      CA
# 49     3000128        NaN                NaN      6691.0      CA
# 52     3000135        NaN                NaN      4276.0      CA
# 53     3000137        NaN                NaN     44088.0      TX
# 54     3000138        NaN                NaN     16090.0      CA
# 55     3000139        NaN                NaN      3817.0      CA
# 59     3000153        NaN                NaN      3138.0      CA
# 61     3000164        NaN                NaN      4312.0      CA
# ...        ...        ...                ...         ...     ...
# 59722  3091966        NaN   2015-WTW-4955-OE         NaN      TX
# 59729  3091984        NaN   2015-WTW-4956-OE         NaN      TX
# 59730  3091987  04-020384  2011-WTW-12020-OE         NaN      AZ
# 59741  3092008  48-024042   2009-WTW-3509-OE         NaN      TX
# 59742  3092009        NaN   2015-WTW-4954-OE         NaN      TX
# 59743  3092010        NaN  2017-WTW-10123-OE         NaN      TX
# 59746  3092014  04-020398  2011-WTW-13257-OE         NaN      AZ
# 59778  3092057        NaN  2017-WTW-10180-OE         NaN      TX
# 59779  3092058        NaN  2017-WTW-10122-OE         NaN      TX
# 59791  3092088  04-020351  2011-WTW-13399-OE         NaN      AZ
# 59792  3092090  04-020385  2011-WTW-13325-OE         NaN      AZ
# 59793  3092091  04-020382  2011-WTW-12540-OE         NaN      AZ
# 59794  3092092  04-020374  2011-WTW-11976-OE         NaN      AZ
# 59795  3092095  06-023262  2011-WTW-10212-OE         NaN      CA
# 59796  3092103  48-015078   2004-ASW-2938-OE         NaN      TX
# 59798  3092110        NaN   2015-WTW-4991-OE         NaN      TX
# 59799  3092111        NaN   2015-WTW-5009-OE         NaN      TX
# 59806  3092123  06-030744   2012-WTW-7300-OE         NaN      CA
# 59807  3092124  04-020353  2011-WTW-13390-OE         NaN      AZ
# 59811  3092134  04-020367  2011-WTW-12970-OE         NaN      AZ
# 59812  3092136  04-020342  2010-WTW-16977-OE         NaN      AZ
# 59820  3092150  04-020379  2011-WTW-12430-OE         NaN      AZ
# 59821  3092151  04-020358  2011-WTW-12576-OE         NaN      AZ
# 59822  3092153        NaN  2017-WTW-10114-OE         NaN      TX
# 59831  3092168  04-020375  2011-WTW-11977-OE         NaN      AZ
# 59849  3092206        NaN  2017-WTW-10158-OE         NaN      TX
# 59855  3092218        NaN   2015-WTW-4990-OE         NaN      TX
# 59857  3092222  04-020392  2011-WTW-12574-OE         NaN      AZ
# 59867  3092263        NaN                NaN         NaN      IL
# 59868  3092264        NaN                NaN         NaN      IL
#
#                t_county  t_fips                                  p_name  \
# 2           Kern County    6029  unknown Tehachapi Wind Resource Area 1
# 4           Kern County    6029  unknown Tehachapi Wind Resource Area 1
# 5      Riverside County    6065                       Alta Mesa 1 and 2
# 12        Merced County    6047   International Turbine Research Center
# 13          Kern County    6029  unknown Tehachapi Wind Resource Area 1
# 14          Kern County    6029  unknown Tehachapi Wind Resource Area 1
# 17          Kern County    6029  unknown Tehachapi Wind Resource Area 1
# 19          Kern County    6029                   Tehachapi Windplant I
# 22          Kern County    6029  unknown Tehachapi Wind Resource Area 1
# 23          Kern County    6029                               Sky River
# 24          Kern County    6029  unknown Tehachapi Wind Resource Area 1
#
# 59821  2012.0      62  ...   9/10/2018  Digital Globe -112.283722  35.415367
# 59822  2018.0     569  ...    4/9/2019  Digital Globe -102.100113  30.914520
# 59831  2012.0      62  ...   9/10/2018  Digital Globe -112.316742  35.475113
# 59849  2018.0     569  ...    4/9/2019  Digital Globe -102.146860  30.923461
# 59855  2019.0     569  ...  11/24/2018  Digital Globe -102.303383  35.193565
# 59857  2012.0      62  ...   9/10/2018  Digital Globe -112.292519  35.413643
# 59867  2019.0      29  ...   4/26/2019  Digital Globe  -89.036102  41.725716
# 59868  2019.0      29  ...   4/26/2019  Digital Globe  -89.060822  41.735920
#
#            KW        Long        Lat  prediction  filenames     id
# 2         NaN -118.299385  35.044796    1.000000      3.tif      3
# 4         NaN -118.302778  35.078526    1.000000      5.tif      5
# 5       160.0 -116.666191  33.944595    1.000000      6.tif      6
# 12      105.0 -121.170878  37.035723    1.000000     13.tif     13
# 13        NaN -118.267090  35.072395    1.000000     14.tif     14
# 14        NaN -118.370839  35.073111    0.999797     15.tif     15
# 17        NaN -118.253685  35.079994    1.000000     18.tif     18
# 19       65.0 -118.387375  35.058311    0.998029     20.tif     20
# 22        NaN -118.299286  35.119293    0.999989     23.tif     23
# 23      225.0 -118.238991  35.240494    0.999992     24.tif     24
# 24        NaN -118.262886  35.093796    1.000000     25.tif     25
# 25     1000.0 -118.296288  35.067696    1.000000     26.tif     26
# 26       65.0 -118.391983  35.059254    0.993035     27.tif     27
# 29      500.0 -116.630142  33.923340    0.999998     30.tif     30
# 30       65.0 -121.611084  37.691296    1.000000     31.tif     31
# 32       65.0 -121.614293  37.696745    1.000000     33.tif     33
# 33        NaN -118.284592  35.040894    1.000000     34.tif     34
# 37        NaN -118.237488  35.106895    1.000000     38.tif     38
# 38      600.0  -93.653793  43.266293    0.999961     39.tif     39
# 40        NaN -118.270287  35.044895    1.000000     41.tif     41
# 41      700.0 -116.573486  33.905193    1.000000     42.tif     42
# 42        NaN -118.343736  35.060982    1.000000     43.tif     43
# 46        NaN -118.247185  35.074795    1.000000     47.tif     47
# 49        NaN -118.267990  35.070995    0.999999     50.tif     50
# 52        NaN -118.294685  35.126694    0.995399     53.tif     53
# 53      700.0 -102.119492  31.078196    1.000000     54.tif     54
# 54      225.0 -116.666227  33.946156    1.000000     55.tif     55
# 55        NaN -118.250092  35.100094    1.000000     56.tif     56
# 59     1000.0 -118.304985  35.062294    0.999995     60.tif     60
# 61        NaN -118.292686  35.123596    0.999970     62.tif     62
# ...       ...         ...        ...         ...        ...    ...
# 59722     NaN -102.280556  35.210056    1.000000  59723.tif  59723
# 59729     NaN -102.276825  35.208557    1.000000  59730.tif  59730
# 59730  1600.0 -112.319672  35.469322    1.000000  59731.tif  59731
# 59741  2400.0  -97.592133  27.116028    1.000000  59742.tif  59742
# 59742     NaN -102.284309  35.211716    1.000000  59743.tif  59743
# 59743     NaN -102.108539  30.915024    0.999986  59744.tif  59744
# 59746  1600.0 -112.222221  35.439030    0.999934  59747.tif  59747
# 59778     NaN -102.144130  30.935381    1.000000  59779.tif  59779
# 59779     NaN -102.111118  30.914952    1.000000  59780.tif  59780
# 59791  1600.0 -112.312096  35.366337    1.000000  59792.tif  59792
# 59792  1600.0 -112.331169  35.372223    1.000000  59793.tif  59793
# 59793  1600.0 -112.331398  35.432354    1.000000  59794.tif  59794
# 59794  1600.0 -112.319435  35.477657    1.000000  59795.tif  59795
# 59795  2370.0 -116.033081  32.738369    1.000000  59796.tif  59796
# 59796  1500.0 -100.002245  32.314624    0.999974  59797.tif  59797
# 59798     NaN -102.299652  35.192066    1.000000  59799.tif  59799
# 59799     NaN -102.290878  35.185665    1.000000  59800.tif  59800
# 59806  2300.0 -115.996704  32.707851    1.000000  59807.tif  59807
# 59807  1600.0 -112.305405  35.367451    1.000000  59808.tif  59808
# 59811  1600.0 -112.223038  35.458282    1.000000  59812.tif  59812
# 59812  1600.0 -112.274109  35.407253    1.000000  59813.tif  59813
# 59820  1600.0 -112.333954  35.455635    1.000000  59821.tif  59821
# 59821  1600.0 -112.283722  35.415367    1.000000  59822.tif  59822
# 59822     NaN -102.100113  30.914520    1.000000  59823.tif  59823
# 59831  1600.0 -112.316742  35.475113    1.000000  59832.tif  59832
# 59849     NaN -102.146860  30.923461    1.000000  59850.tif  59850
# 59855     NaN -102.303383  35.193565    1.000000  59856.tif  59856
# 59857  1600.0 -112.292519  35.413643    1.000000  59858.tif  59858
# 59867  2625.0  -89.036102  41.725716    0.999998  59868.tif  59868
# 59868  2625.0  -89.060822  41.735920    1.000000  59869.tif  59869
#
# [47665 rows x 30 columns]

# %%
cnt = 0
flag = False

for i in range(0, nmb_samples_all):
    
        
        
    #print(file)
    file_s = str(turbines_us.iloc[[i]]['id'].values[0]) + '.tif'
    file_d = str(turbines_us.iloc[[i]]['id'].values[0]) + '.png'
    
    #print(file)
        
    src = os.path.join(src_dir_tb, file_s)
        
    if(cnt % 1000 == 0):
        print(cnt)
        print(src)
            
    #print(src)
        
        
        
    if(os.path.isfile(src)):
            
        dst = ""
        
        if(cnt < share_train):
           
            dst = os.path.join(train_dir, file_d)
            
        if(cnt > share_train):
                
            
            if(not flag):
                print("test files here")
                print(dst)
            
            dst = os.path.join(test_dir, file_d)
            
            if(not flag):
                print(dst)

        fpr.copyfile_to_png(src, dst)
        cnt += 1
    else:
        print("no")
        print(src)
# Out:
# 0
# data/aerialImages/GOOGLE/RESOLUTION19/US/raw/Turbines/3.tif
# 1000
# data/aerialImages/GOOGLE/RESOLUTION19/US/raw/Turbines/1828.tif

# %%
print('total training turbine images ', len(os.listdir(train_dir)))
print('total testing turbine images ', len(os.listdir(test_dir)))

pd_out = turbines_us['id'].map(str) + '.png'
pd_out['score'] = turbines_us['t_hh']

share_train_i = int(np.floor(share_train))

pd_out_train = pd_out.iloc[0: share_train_i]
pd_out_test = pd_out.iloc[((share_train_i) + 1) : pd_out.shape[0]]
                                      
pd_out_train.to_csv(train_dir + "list.csv")
pd_out_test.to_csv(test_dir + "list.csv")

# %%
print(len(os.listdir(train_dir)))
print(pd_out_train.shape)
print(share_train)
print(share_train_i)
