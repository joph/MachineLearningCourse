# %%
cd /data/projects/windturbine-identification/MachineLearningCourse/
# Out:
# /data/projects/windturbine-identification/MachineLearningCourse

# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Jun 14 13:28:53 2019

@author: jschmidt
"""

# -*- coding: utf-8 -*-
"""
Created on Wed Mar  6 12:33:58 2019

@author: jschmidt
"""

import os
from keras import models
import imp
import scripts.windturbines.functions_pattern_recognition as fpr
imp.reload(fpr)
import pandas as pd
# Out:
# Using TensorFlow backend.

# %%
# Get images from raw directory
# Convert to png in temp
# Predict
# If classified, copy

model = models.load_model('models/model-0005-0.0191.h5')

# within this file, we assess new regions
COUNTRY = "DE"

raw_dir = fpr.get_param(COUNTRY, "PATH_RAW_IMAGES_OSM")
temp_dir = fpr.get_param(COUNTRY, "PATH_TEMP")

lon_lat = pd.read_csv(fpr.get_param(COUNTRY, "FILE_OSM_TURBINE_LOCATIONS"))


files = []

for i in range(lon_lat.shape[0]):
    files.append(str(i + 1) + ".tif")

lon_lat["filenames"] = files

lon_lat["prediction"] = 0

for i in range(len(files)):
    
    
    f = files[i]
    
    if(i%1000 == 0):
        print("File " + f)

        
    src = raw_dir + f
    dst = temp_dir + f[:-4] + "_osm-assessment.png"
            
    element = fpr.assess_location(f, src, dst, "", model)
    
    lon_lat.iloc[i, 3] = element[1]
# Out:
# WARNING:tensorflow:From /home/jschmidt/.conda/envs/windturbine-identification/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/jschmidt/.conda/envs/windturbine-identification/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# File 1.tif
# File 1001.tif
# File 2001.tif
# File 3001.tif
# File 4001.tif
# File 5001.tif
# File 6001.tif
# File 7001.tif
# File 8001.tif
# File 9001.tif
# File 10001.tif
# Exception gdal 10198.tif
# Received a NULL pointer.
# Exception gdal 10199.tif
# Received a NULL pointer.
# Exception gdal 10200.tif
# Received a NULL pointer.
# Exception gdal 10201.tif
# Received a NULL pointer.
# Exception gdal 10202.tif
# Received a NULL pointer.
# Exception gdal 10203.tif
# Received a NULL pointer.
# Exception gdal 10204.tif
# Received a NULL pointer.
# Exception gdal 10205.tif
# Received a NULL pointer.
# Exception gdal 10206.tif
# Received a NULL pointer.
# Exception gdal 10207.tif
# Received a NULL pointer.
# Exception gdal 10208.tif
# Received a NULL pointer.
# Exception gdal 10209.tif
# Received a NULL pointer.
# Exception gdal 10210.tif
# Received a NULL pointer.
# Exception gdal 10211.tif
# Received a NULL pointer.
# Exception gdal 10212.tif
# Received a NULL pointer.
# Exception gdal 10213.tif
# Received a NULL pointer.
# Exception gdal 10214.tif
# Received a NULL pointer.
# Exception gdal 10215.tif
# Received a NULL pointer.
# Exception gdal 10216.tif
# Received a NULL pointer.
# Exception gdal 10217.tif
# Received a NULL pointer.
# Exception gdal 10218.tif
# Received a NULL pointer.
# File 11001.tif
# File 12001.tif
# File 13001.tif
# File 14001.tif
# Exception gdal 14111.tif
# Received a NULL pointer.
# Exception gdal 14112.tif
# Received a NULL pointer.
# Exception gdal 14113.tif
# Received a NULL pointer.
# Exception gdal 14114.tif
# Received a NULL pointer.
# Exception gdal 14115.tif
# Received a NULL pointer.
# Exception gdal 14116.tif
# Received a NULL pointer.
# Exception gdal 14117.tif
# Received a NULL pointer.
# Exception gdal 14118.tif
# Received a NULL pointer.
# Exception gdal 14119.tif
# Received a NULL pointer.
# Exception gdal 14120.tif
# Received a NULL pointer.
# Exception gdal 14121.tif
# Received a NULL pointer.
# Exception gdal 14122.tif
# Received a NULL pointer.
# Exception gdal 14123.tif
# Received a NULL pointer.
# Exception gdal 14124.tif
# Received a NULL pointer.
# Exception gdal 14125.tif
# Received a NULL pointer.
# Exception gdal 14126.tif
# Received a NULL pointer.
# Exception gdal 14127.tif
# Received a NULL pointer.
# Exception gdal 14128.tif
# Received a NULL pointer.
# Exception gdal 14129.tif
# Received a NULL pointer.
# Exception gdal 14130.tif
# Received a NULL pointer.
# Exception gdal 14131.tif
# Received a NULL pointer.
# Exception gdal 14132.tif
# Received a NULL pointer.
# Exception gdal 14133.tif
# Received a NULL pointer.
# Exception gdal 14134.tif
# Received a NULL pointer.
# Exception gdal 14135.tif
# Received a NULL pointer.
# Exception gdal 14136.tif
# Received a NULL pointer.
# Exception gdal 14137.tif
# Received a NULL pointer.
# Exception gdal 14138.tif
# Received a NULL pointer.
# Exception gdal 14139.tif
# Received a NULL pointer.
# Exception gdal 14140.tif
# Received a NULL pointer.
# File 15001.tif
# File 16001.tif
# File 17001.tif
# File 18001.tif
# File 19001.tif
# File 20001.tif
# Exception gdal 20956.tif
# Received a NULL pointer.
# Exception gdal 20957.tif
# Received a NULL pointer.
# Exception gdal 20958.tif
# Received a NULL pointer.
# File 21001.tif
# File 22001.tif
# File 23001.tif
# File 24001.tif
# File 25001.tif
# File 26001.tif
# File 27001.tif

# %%
lon_lat.to_csv(fpr.get_param(COUNTRY, "FILE_OSM_TURBINE_LOCATIONS") + "assessment.csv")

# %%
lon_lat.shape
# Out:
# (27002, 4)
