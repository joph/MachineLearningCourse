# %%
cd /data/projects/windturbine-identification/MachineLearningCourse/
# Out:
# /data/projects/windturbine-identification/MachineLearningCourse

# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Jun 14 13:28:53 2019

@author: jschmidt
"""

# -*- coding: utf-8 -*-
"""
Created on Wed Mar  6 12:33:58 2019

@author: jschmidt
"""

import os
from keras import models
import imp
import scripts.windturbines.functions_pattern_recognition as fpr
imp.reload(fpr)
import pandas as pd

# %%
# Get images from raw directory
# Convert to png in temp
# Predict
# If classified, copy

model = models.load_model('models/model-0005-0.0191.h5')


countries = ['CN', 'IN', 'ES', 'GB', 'FR', 'BR', 'CA']
# within this file, we assess new regions

# %%
predictions = pd.DataFrame(columns=['lon', 'lat', 'prediction', 'filenames', 'directory', 'country'])

# %%
for COUNTRY in countries:

    print("--------Current country: " + COUNTRY + "--------")

    raw_dir = fpr.get_param(COUNTRY, "PATH_RAW_IMAGES_OSM")
    temp_dir = fpr.get_param(COUNTRY, "PATH_TEMP")

    lon_lat = pd.read_csv(fpr.get_param(COUNTRY, "FILE_OSM_TURBINE_LOCATIONS"))


    files = []

    for i in range(lon_lat.shape[0]):
        files.append(str(i + 1) + ".tif")

   
    for i in range(len(files)):
    
    
        f = files[i]

        if(i%1000 == 0):
            print("File " + f)


        src = raw_dir + f
        dst = temp_dir + f[:-4] + "_osm-assessment.png"

        element = fpr.assess_location(f, src, dst, "", model)
        
        predictions = predictions.append({"lon" : lon_lat.Long[i], "lat" : lon_lat.Lat[i], 
                            "prediction" : element[1], "filenames" : f, 
                            "directory" : "", "country" : COUNTRY}, ignore_index = True)
# Out:
# --------Current country: CN--------
# File 1.tif
# Exception gdal 1.tif
# Received a NULL pointer.
# File 1001.tif
# Exception gdal 1944.tif
# Received a NULL pointer.
# Exception gdal 1945.tif
# Received a NULL pointer.
# Exception gdal 1946.tif
# Received a NULL pointer.
# Exception gdal 1947.tif
# Received a NULL pointer.
# Exception gdal 1948.tif
# Received a NULL pointer.
# Exception gdal 1949.tif
# Received a NULL pointer.
# Exception gdal 1950.tif
# Received a NULL pointer.
# Exception gdal 1951.tif
# Received a NULL pointer.
# Exception gdal 1952.tif
# Received a NULL pointer.
# Exception gdal 1953.tif
# Received a NULL pointer.
# Exception gdal 1954.tif
# Received a NULL pointer.
# Exception gdal 1955.tif
# Received a NULL pointer.
# Exception gdal 1956.tif
# Received a NULL pointer.
# Exception gdal 1957.tif
# Received a NULL pointer.
# Exception gdal 1958.tif
# Received a NULL pointer.
# Exception gdal 1959.tif
# Received a NULL pointer.
# Exception gdal 1960.tif
# Received a NULL pointer.
# Exception gdal 1961.tif
# Received a NULL pointer.
# Exception gdal 1962.tif
# Received a NULL pointer.
# Exception gdal 1963.tif
# Received a NULL pointer.
# Exception gdal 1964.tif
# Received a NULL pointer.
# Exception gdal 1965.tif
# Received a NULL pointer.
# Exception gdal 1966.tif
# Received a NULL pointer.
# Exception gdal 1967.tif
# Received a NULL pointer.
# Exception gdal 1968.tif
# Received a NULL pointer.
# Exception gdal 1969.tif
# Received a NULL pointer.
# Exception gdal 1970.tif
# Received a NULL pointer.
# Exception gdal 1971.tif
# Received a NULL pointer.
# Exception gdal 1972.tif
# Received a NULL pointer.
# Exception gdal 1973.tif
# Received a NULL pointer.
# Exception gdal 1974.tif
# Received a NULL pointer.
# Exception gdal 1975.tif
# Received a NULL pointer.
# Exception gdal 1976.tif
# Received a NULL pointer.
# Exception gdal 1977.tif
# Received a NULL pointer.
# Exception gdal 1978.tif
# Received a NULL pointer.
# Exception gdal 1979.tif
# Received a NULL pointer.
# Exception gdal 1980.tif
# Received a NULL pointer.
# Exception gdal 1981.tif
# Received a NULL pointer.
# Exception gdal 1982.tif
# Received a NULL pointer.
# Exception gdal 1983.tif
# Received a NULL pointer.
# Exception gdal 1984.tif
# Received a NULL pointer.
# Exception gdal 1985.tif
# Received a NULL pointer.
# Exception gdal 1986.tif
# Received a NULL pointer.
# Exception gdal 1987.tif
# Received a NULL pointer.
# Exception gdal 1988.tif
# Received a NULL pointer.
# Exception gdal 1989.tif
# Received a NULL pointer.
# Exception gdal 1990.tif
# Received a NULL pointer.
# Exception gdal 1991.tif
# Received a NULL pointer.
# Exception gdal 1992.tif
# Received a NULL pointer.
# Exception gdal 1993.tif
# Received a NULL pointer.
# Exception gdal 1994.tif
# Received a NULL pointer.
# Exception gdal 1995.tif
# Received a NULL pointer.
# Exception gdal 1996.tif
# Received a NULL pointer.
# Exception gdal 1997.tif
# Received a NULL pointer.
# Exception gdal 1998.tif
# Received a NULL pointer.
# Exception gdal 1999.tif
# Received a NULL pointer.
# Exception gdal 2000.tif
# Received a NULL pointer.
# File 2001.tif
# Exception gdal 2001.tif
# Received a NULL pointer.
# Exception gdal 2002.tif
# Received a NULL pointer.
# Exception gdal 2003.tif
# Received a NULL pointer.
# Exception gdal 2004.tif
# Received a NULL pointer.
# Exception gdal 2006.tif
# Received a NULL pointer.
# Exception gdal 2007.tif
# Received a NULL pointer.
# Exception gdal 2008.tif
# Received a NULL pointer.
# Exception gdal 2009.tif
# Received a NULL pointer.
# Exception gdal 2010.tif
# Received a NULL pointer.
# Exception gdal 2011.tif
# Received a NULL pointer.
# Exception gdal 2013.tif
# Received a NULL pointer.
# Exception gdal 2015.tif
# Received a NULL pointer.
# Exception gdal 2016.tif
# Received a NULL pointer.
# Exception gdal 2017.tif
# Received a NULL pointer.
# Exception gdal 2018.tif
# Received a NULL pointer.
# Exception gdal 2020.tif
# Received a NULL pointer.
# Exception gdal 2022.tif
# Received a NULL pointer.
# Exception gdal 2023.tif
# Received a NULL pointer.
# Exception gdal 2024.tif
# Received a NULL pointer.
# Exception gdal 2025.tif
# Received a NULL pointer.
# Exception gdal 2026.tif
# Received a NULL pointer.
# Exception gdal 2027.tif
# Received a NULL pointer.
# Exception gdal 2029.tif
# Received a NULL pointer.
# Exception gdal 2030.tif
# Received a NULL pointer.
# Exception gdal 2031.tif
# Received a NULL pointer.
# Exception gdal 2032.tif
# Received a NULL pointer.
# Exception gdal 2033.tif
# Received a NULL pointer.
# Exception gdal 2036.tif
# Received a NULL pointer.
# Exception gdal 2037.tif
# Received a NULL pointer.
# Exception gdal 2038.tif
# Received a NULL pointer.
# Exception gdal 2039.tif
# Received a NULL pointer.
# Exception gdal 2040.tif
# Received a NULL pointer.
# Exception gdal 2041.tif
# Received a NULL pointer.
# Exception gdal 2042.tif
# Received a NULL pointer.
# Exception gdal 2043.tif
# Received a NULL pointer.
# Exception gdal 2045.tif
# Received a NULL pointer.
# Exception gdal 2046.tif
# Received a NULL pointer.
# Exception gdal 2047.tif
# Received a NULL pointer.
# Exception gdal 2049.tif
# Received a NULL pointer.
# Exception gdal 2050.tif
# Received a NULL pointer.
# Exception gdal 2051.tif
# Received a NULL pointer.
# Exception gdal 2053.tif
# Received a NULL pointer.
# Exception gdal 2054.tif
# Received a NULL pointer.
# Exception gdal 2056.tif
# Received a NULL pointer.
# Exception gdal 2057.tif
# Received a NULL pointer.
# Exception gdal 2058.tif
# Received a NULL pointer.
# Exception gdal 2059.tif
# Received a NULL pointer.
# Exception gdal 2061.tif
# Received a NULL pointer.
# Exception gdal 2062.tif
# Received a NULL pointer.
# Exception gdal 2064.tif
# Received a NULL pointer.
# Exception gdal 2065.tif
# Received a NULL pointer.
# Exception gdal 2067.tif
# Received a NULL pointer.
# Exception gdal 2068.tif
# Received a NULL pointer.
# Exception gdal 2069.tif
# Received a NULL pointer.
# Exception gdal 2072.tif
# Received a NULL pointer.
# Exception gdal 2073.tif
# Received a NULL pointer.
# Exception gdal 2074.tif
# Received a NULL pointer.
# Exception gdal 2076.tif
# Received a NULL pointer.
# Exception gdal 2077.tif
# Received a NULL pointer.
# Exception gdal 2080.tif
# Received a NULL pointer.
# Exception gdal 2081.tif
# Received a NULL pointer.
# Exception gdal 2083.tif
# Received a NULL pointer.
# Exception gdal 2084.tif
# Received a NULL pointer.
# Exception gdal 2087.tif
# Received a NULL pointer.
# Exception gdal 2088.tif
# Received a NULL pointer.
# Exception gdal 2089.tif
# Received a NULL pointer.
# Exception gdal 2090.tif
# Received a NULL pointer.
# Exception gdal 2093.tif
# Received a NULL pointer.
# Exception gdal 2094.tif
# Received a NULL pointer.
# Exception gdal 2095.tif
# Received a NULL pointer.
# Exception gdal 2096.tif
# Received a NULL pointer.
# Exception gdal 2099.tif
# Received a NULL pointer.
# Exception gdal 2100.tif
# Received a NULL pointer.
# Exception gdal 2101.tif
# Received a NULL pointer.
# Exception gdal 2102.tif
# Received a NULL pointer.
# Exception gdal 2105.tif
# Received a NULL pointer.
# Exception gdal 2106.tif
# Received a NULL pointer.
# Exception gdal 2118.tif
# Received a NULL pointer.
# Exception gdal 2121.tif
# Received a NULL pointer.
# Exception gdal 2124.tif
# Received a NULL pointer.
# Exception gdal 2138.tif
# Received a NULL pointer.
# Exception gdal 2140.tif
# Received a NULL pointer.
# Exception gdal 2143.tif
# Received a NULL pointer.
# Exception gdal 2145.tif
# Received a NULL pointer.
# Exception gdal 2146.tif
# Received a NULL pointer.
# Exception gdal 2147.tif
# Received a NULL pointer.
# Exception gdal 2148.tif
# Received a NULL pointer.
# Exception gdal 2149.tif
# Received a NULL pointer.
# Exception gdal 2150.tif
# Received a NULL pointer.
# Exception gdal 2151.tif
# Received a NULL pointer.
# Exception gdal 2152.tif
# Received a NULL pointer.
# Exception gdal 2153.tif
# Received a NULL pointer.
# Exception gdal 2154.tif
# Received a NULL pointer.
# Exception gdal 2155.tif
# Received a NULL pointer.
# Exception gdal 2156.tif
# Received a NULL pointer.
# Exception gdal 2157.tif
# Received a NULL pointer.
# Exception gdal 2158.tif
# Received a NULL pointer.
# Exception gdal 2159.tif
# Received a NULL pointer.
# Exception gdal 2160.tif
# Received a NULL pointer.
# Exception gdal 2161.tif
# Received a NULL pointer.
# Exception gdal 2162.tif
# Received a NULL pointer.
# Exception gdal 2163.tif
# Received a NULL pointer.
# Exception gdal 2164.tif
# Received a NULL pointer.
# Exception gdal 2165.tif
# Received a NULL pointer.
# Exception gdal 2166.tif
# Received a NULL pointer.
# Exception gdal 2167.tif
# Received a NULL pointer.
# Exception gdal 2168.tif
# Received a NULL pointer.
# Exception gdal 2169.tif
# Received a NULL pointer.
# Exception gdal 2170.tif
# Received a NULL pointer.
# Exception gdal 2171.tif
# Received a NULL pointer.
# Exception gdal 2172.tif
# Received a NULL pointer.
# Exception gdal 2173.tif
# Received a NULL pointer.
# Exception gdal 2174.tif
# Received a NULL pointer.
# Exception gdal 2175.tif
# Received a NULL pointer.
# Exception gdal 2176.tif
# Received a NULL pointer.
# Exception gdal 2177.tif
# Received a NULL pointer.
# Exception gdal 2178.tif
# Received a NULL pointer.
# Exception gdal 2179.tif
# Received a NULL pointer.
# Exception gdal 2180.tif
# Received a NULL pointer.
# Exception gdal 2181.tif
# Received a NULL pointer.
# Exception gdal 2182.tif
# Received a NULL pointer.
# Exception gdal 2183.tif
# Received a NULL pointer.
# Exception gdal 2184.tif
# Received a NULL pointer.
# Exception gdal 2185.tif
# Received a NULL pointer.
# Exception gdal 2186.tif
# Received a NULL pointer.
# Exception gdal 2187.tif
# Received a NULL pointer.
# Exception gdal 2188.tif
# Received a NULL pointer.
# Exception gdal 2189.tif
# Received a NULL pointer.
# Exception gdal 2190.tif
# Received a NULL pointer.
# Exception gdal 2191.tif
# Received a NULL pointer.
# Exception gdal 2192.tif
# Received a NULL pointer.
# Exception gdal 2193.tif
# Received a NULL pointer.
# Exception gdal 2194.tif
# Received a NULL pointer.
# Exception gdal 2195.tif
# Received a NULL pointer.
# Exception gdal 2196.tif
# Received a NULL pointer.
# Exception gdal 2197.tif
# Received a NULL pointer.
# Exception gdal 2198.tif
# Received a NULL pointer.
# Exception gdal 2199.tif
# Received a NULL pointer.
# Exception gdal 2200.tif
# Received a NULL pointer.
# Exception gdal 2201.tif
# Received a NULL pointer.
# File 3001.tif
# File 4001.tif
# File 5001.tif
# Exception gdal 5163.tif
# Received a NULL pointer.
# Exception gdal 5164.tif
# Received a NULL pointer.
# Exception gdal 5165.tif
# Received a NULL pointer.
# Exception gdal 5166.tif
# Received a NULL pointer.
# Exception gdal 5167.tif
# Received a NULL pointer.
# Exception gdal 5168.tif
# Received a NULL pointer.
# Exception gdal 5169.tif
# Received a NULL pointer.
# Exception gdal 5170.tif
# Received a NULL pointer.
# Exception gdal 5171.tif
# Received a NULL pointer.
# Exception gdal 5172.tif
# Received a NULL pointer.
# Exception gdal 5173.tif
# Received a NULL pointer.
# Exception gdal 5174.tif
# Received a NULL pointer.
# Exception gdal 5175.tif
# Received a NULL pointer.
# Exception gdal 5176.tif
# Received a NULL pointer.
# Exception gdal 5177.tif
# Received a NULL pointer.
# Exception gdal 5178.tif
# Received a NULL pointer.
# Exception gdal 5179.tif
# Received a NULL pointer.
# Exception gdal 5180.tif
# Received a NULL pointer.
# Exception gdal 5181.tif
# Received a NULL pointer.
# Exception gdal 5182.tif
# Received a NULL pointer.
# Exception gdal 5183.tif
# Received a NULL pointer.
# Exception gdal 5184.tif
# Received a NULL pointer.
# Exception gdal 5185.tif
# Received a NULL pointer.
# Exception gdal 5186.tif
# Received a NULL pointer.
# Exception gdal 5187.tif
# Received a NULL pointer.
# Exception gdal 5188.tif
# Received a NULL pointer.
# Exception gdal 5189.tif
# Received a NULL pointer.
# Exception gdal 5190.tif
# Received a NULL pointer.
# Exception gdal 5191.tif
# Received a NULL pointer.
# Exception gdal 5192.tif
# Received a NULL pointer.
# Exception gdal 5193.tif
# Received a NULL pointer.
# Exception gdal 5194.tif
# Received a NULL pointer.
# Exception gdal 5195.tif
# Received a NULL pointer.
# Exception gdal 5196.tif
# Received a NULL pointer.
# Exception gdal 5197.tif
# Received a NULL pointer.
# Exception gdal 5198.tif
# Received a NULL pointer.
# Exception gdal 5199.tif
# Received a NULL pointer.
# Exception gdal 5200.tif
# Received a NULL pointer.
# Exception gdal 5201.tif
# Received a NULL pointer.
# Exception gdal 5202.tif
# Received a NULL pointer.
# Exception gdal 5203.tif
# Received a NULL pointer.
# Exception gdal 5204.tif
# Received a NULL pointer.
# Exception gdal 5205.tif
# Received a NULL pointer.
# Exception gdal 5206.tif
# Received a NULL pointer.
# Exception gdal 5207.tif
# Received a NULL pointer.
# Exception gdal 5208.tif
# Received a NULL pointer.
# Exception gdal 5209.tif
# Received a NULL pointer.
# Exception gdal 5210.tif
# Received a NULL pointer.
# Exception gdal 5211.tif
# Received a NULL pointer.
# Exception gdal 5212.tif
# Received a NULL pointer.
# Exception gdal 5213.tif
# Received a NULL pointer.
# Exception gdal 5214.tif
# Received a NULL pointer.
# Exception gdal 5215.tif
# Received a NULL pointer.
# Exception gdal 5216.tif
# Received a NULL pointer.
# Exception gdal 5217.tif
# Received a NULL pointer.
# Exception gdal 5218.tif
# Received a NULL pointer.
# Exception gdal 5219.tif
# Received a NULL pointer.
# Exception gdal 5220.tif
# Received a NULL pointer.
# Exception gdal 5221.tif
# Received a NULL pointer.
# Exception gdal 5222.tif
# Received a NULL pointer.
# Exception gdal 5223.tif
# Received a NULL pointer.
# Exception gdal 5224.tif
# Received a NULL pointer.
# Exception gdal 5225.tif
# Received a NULL pointer.
# Exception gdal 5226.tif
# Received a NULL pointer.
# Exception gdal 5227.tif
# Received a NULL pointer.
# Exception gdal 5228.tif
# Received a NULL pointer.
# Exception gdal 5229.tif
# Received a NULL pointer.
# Exception gdal 5230.tif
# Received a NULL pointer.
# Exception gdal 5231.tif
# Received a NULL pointer.
# Exception gdal 5232.tif
# Received a NULL pointer.
# Exception gdal 5233.tif
# Received a NULL pointer.
# Exception gdal 5234.tif
# Received a NULL pointer.
# Exception gdal 5235.tif
# Received a NULL pointer.
# Exception gdal 5236.tif
# Received a NULL pointer.
# Exception gdal 5237.tif
# Received a NULL pointer.
# Exception gdal 5238.tif
# Received a NULL pointer.
# Exception gdal 5239.tif
# Received a NULL pointer.
# Exception gdal 5240.tif
# Received a NULL pointer.
# Exception gdal 5241.tif
# Received a NULL pointer.
# Exception gdal 5242.tif
# Received a NULL pointer.
# Exception gdal 5243.tif
# Received a NULL pointer.
# Exception gdal 5244.tif
# Received a NULL pointer.
# Exception gdal 5245.tif
# Received a NULL pointer.
# Exception gdal 5246.tif
# Received a NULL pointer.
# File 6001.tif
# Exception gdal 6690.tif
# Received a NULL pointer.
# Exception gdal 6691.tif
# Received a NULL pointer.
# Exception gdal 6692.tif
# Received a NULL pointer.
# Exception gdal 6693.tif
# Received a NULL pointer.
# Exception gdal 6694.tif
# Received a NULL pointer.
# Exception gdal 6695.tif
# Received a NULL pointer.
# Exception gdal 6697.tif
# Received a NULL pointer.
# Exception gdal 6698.tif
# Received a NULL pointer.
# Exception gdal 6700.tif
# Received a NULL pointer.
# Exception gdal 6701.tif
# Received a NULL pointer.
# Exception gdal 6702.tif
# Received a NULL pointer.
# Exception gdal 6705.tif
# Received a NULL pointer.
# Exception gdal 6707.tif
# Received a NULL pointer.
# Exception gdal 6709.tif
# Received a NULL pointer.
# Exception gdal 6710.tif
# Received a NULL pointer.
# Exception gdal 6713.tif
# Received a NULL pointer.
# Exception gdal 6714.tif
# Received a NULL pointer.
# Exception gdal 6716.tif
# Received a NULL pointer.
# Exception gdal 6717.tif
# Received a NULL pointer.
# Exception gdal 6718.tif
# Received a NULL pointer.
# Exception gdal 6721.tif
# Received a NULL pointer.
# Exception gdal 6723.tif
# Received a NULL pointer.
# Exception gdal 6724.tif
# Received a NULL pointer.
# Exception gdal 6727.tif
# Received a NULL pointer.
# Exception gdal 6730.tif
# Received a NULL pointer.
# Exception gdal 6732.tif
# Received a NULL pointer.
# Exception gdal 6736.tif
# Received a NULL pointer.
# Exception gdal 6741.tif
# Received a NULL pointer.
# Exception gdal 6747.tif
# Received a NULL pointer.
# Exception gdal 6748.tif
# Received a NULL pointer.
# Exception gdal 6755.tif
# Received a NULL pointer.
# Exception gdal 6883.tif
# Received a NULL pointer.
# File 7001.tif
# Exception gdal 7824.tif
# Received a NULL pointer.
# Exception gdal 7825.tif
# Received a NULL pointer.
# Exception gdal 7826.tif
# Received a NULL pointer.
# Exception gdal 7827.tif
# Received a NULL pointer.
# Exception gdal 7828.tif
# Received a NULL pointer.
# Exception gdal 7829.tif
# Received a NULL pointer.
# Exception gdal 7830.tif
# Received a NULL pointer.
# Exception gdal 7831.tif
# Received a NULL pointer.
# Exception gdal 7832.tif
# Received a NULL pointer.
# Exception gdal 7833.tif
# Received a NULL pointer.
# Exception gdal 7834.tif
# Received a NULL pointer.
# Exception gdal 7835.tif
# Received a NULL pointer.
# Exception gdal 7836.tif
# Received a NULL pointer.
# Exception gdal 7837.tif
# Received a NULL pointer.
# Exception gdal 7838.tif
# Received a NULL pointer.
# Exception gdal 7839.tif
# Received a NULL pointer.
# Exception gdal 7840.tif
# Received a NULL pointer.
# Exception gdal 7841.tif
# Received a NULL pointer.
# Exception gdal 7842.tif
# Received a NULL pointer.
# Exception gdal 7843.tif
# Received a NULL pointer.
# Exception gdal 7844.tif
# Received a NULL pointer.
# Exception gdal 7845.tif
# Received a NULL pointer.
# Exception gdal 7846.tif
# Received a NULL pointer.
# Exception gdal 7847.tif
# Received a NULL pointer.
# Exception gdal 7848.tif
# Received a NULL pointer.
# Exception gdal 7849.tif
# Received a NULL pointer.
# Exception gdal 7850.tif
# Received a NULL pointer.
# Exception gdal 7851.tif
# Received a NULL pointer.
# Exception gdal 7852.tif
# Received a NULL pointer.
# Exception gdal 7853.tif
# Received a NULL pointer.
# Exception gdal 7854.tif
# Received a NULL pointer.
# Exception gdal 7855.tif
# Received a NULL pointer.
# Exception gdal 7856.tif
# Received a NULL pointer.
# Exception gdal 7857.tif
# Received a NULL pointer.
# Exception gdal 7858.tif
# Received a NULL pointer.
# Exception gdal 7859.tif
# Received a NULL pointer.
# Exception gdal 7860.tif
# Received a NULL pointer.
# Exception gdal 7861.tif
# Received a NULL pointer.
# Exception gdal 7862.tif
# Received a NULL pointer.
# Exception gdal 7863.tif
# Received a NULL pointer.
# Exception gdal 7864.tif
# Received a NULL pointer.
# Exception gdal 7865.tif
# Received a NULL pointer.
# Exception gdal 7866.tif
# Received a NULL pointer.
# Exception gdal 7867.tif
# Received a NULL pointer.
# Exception gdal 7868.tif
# Received a NULL pointer.
# Exception gdal 7869.tif
# Received a NULL pointer.
# Exception gdal 7870.tif
# Received a NULL pointer.
# Exception gdal 7871.tif
# Received a NULL pointer.
# Exception gdal 7872.tif
# Received a NULL pointer.
# Exception gdal 7873.tif
# Received a NULL pointer.
# Exception gdal 7874.tif
# Received a NULL pointer.
# Exception gdal 7875.tif
# Received a NULL pointer.
# Exception gdal 7876.tif
# Received a NULL pointer.
# Exception gdal 7877.tif
# Received a NULL pointer.
# Exception gdal 7878.tif
# Received a NULL pointer.
# Exception gdal 7879.tif
# Received a NULL pointer.
# Exception gdal 7880.tif
# Received a NULL pointer.
# Exception gdal 7881.tif
# Received a NULL pointer.
# Exception gdal 7882.tif
# Received a NULL pointer.
# Exception gdal 7883.tif
# Received a NULL pointer.
# Exception gdal 7884.tif
# Received a NULL pointer.
# Exception gdal 7898.tif
# Received a NULL pointer.
# Exception gdal 7899.tif
# Received a NULL pointer.
# Exception gdal 7900.tif
# Received a NULL pointer.
# Exception gdal 7901.tif
# Received a NULL pointer.
# Exception gdal 7902.tif
# Received a NULL pointer.
# File 8001.tif
# File 9001.tif
# Exception gdal 9807.tif
# Received a NULL pointer.
# Exception gdal 9809.tif
# Received a NULL pointer.
# Exception gdal 9810.tif
# Received a NULL pointer.
# Exception gdal 9812.tif
# Received a NULL pointer.
# Exception gdal 9819.tif
# Received a NULL pointer.
# Exception gdal 9822.tif
# Received a NULL pointer.
# Exception gdal 9825.tif
# Received a NULL pointer.
# File 10001.tif
# File 11001.tif
# File 12001.tif
# File 13001.tif
# Exception gdal 13363.tif
# Received a NULL pointer.
# Exception gdal 13367.tif
# Received a NULL pointer.
# Exception gdal 13375.tif
# Received a NULL pointer.
# Exception gdal 13393.tif
# Received a NULL pointer.
# File 14001.tif
# File 15001.tif
# File 16001.tif
# Exception gdal 16592.tif
# Received a NULL pointer.
# Exception gdal 16593.tif
# Received a NULL pointer.
# Exception gdal 16595.tif
# Received a NULL pointer.
# Exception gdal 16596.tif
# Received a NULL pointer.
# Exception gdal 16597.tif
# Received a NULL pointer.
# Exception gdal 16598.tif
# Received a NULL pointer.
# Exception gdal 16599.tif
# Received a NULL pointer.
# Exception gdal 16600.tif
# Received a NULL pointer.
# Exception gdal 16601.tif
# Received a NULL pointer.
# Exception gdal 16602.tif
# Received a NULL pointer.
# Exception gdal 16603.tif
# Received a NULL pointer.
# Exception gdal 16604.tif
# Received a NULL pointer.
# Exception gdal 16605.tif
# Received a NULL pointer.
# Exception gdal 16606.tif
# Received a NULL pointer.
# Exception gdal 16607.tif
# Received a NULL pointer.
# Exception gdal 16608.tif
# Received a NULL pointer.
# Exception gdal 16609.tif
# Received a NULL pointer.
# Exception gdal 16611.tif
# Received a NULL pointer.
# Exception gdal 16613.tif
# Received a NULL pointer.
# File 17001.tif
# File 18001.tif
# File 19001.tif
# File 20001.tif
# File 21001.tif
# Exception gdal 21077.tif
# Received a NULL pointer.
# Exception gdal 21079.tif
# Received a NULL pointer.
# Exception gdal 21081.tif
# Received a NULL pointer.
# Exception gdal 21084.tif
# Received a NULL pointer.
# Exception gdal 21087.tif
# Received a NULL pointer.
# Exception gdal 21089.tif
# Received a NULL pointer.
# Exception gdal 21091.tif
# Received a NULL pointer.
# Exception gdal 21093.tif
# Received a NULL pointer.
# Exception gdal 21094.tif
# Received a NULL pointer.
# Exception gdal 21095.tif
# Received a NULL pointer.
# Exception gdal 21096.tif
# Received a NULL pointer.
# Exception gdal 21098.tif
# Received a NULL pointer.
# Exception gdal 21099.tif
# Received a NULL pointer.
# Exception gdal 21100.tif
# Received a NULL pointer.
# Exception gdal 21101.tif
# Received a NULL pointer.
# Exception gdal 21102.tif
# Received a NULL pointer.
# Exception gdal 21103.tif
# Received a NULL pointer.
# Exception gdal 21104.tif
# Received a NULL pointer.
# Exception gdal 21105.tif
# Received a NULL pointer.
# Exception gdal 21106.tif
# Received a NULL pointer.
# Exception gdal 21107.tif
# Received a NULL pointer.
# Exception gdal 21108.tif
# Received a NULL pointer.
# Exception gdal 21109.tif
# Received a NULL pointer.
# Exception gdal 21110.tif
# Received a NULL pointer.
# Exception gdal 21111.tif
# Received a NULL pointer.
# Exception gdal 21112.tif
# Received a NULL pointer.
# Exception gdal 21113.tif
# Received a NULL pointer.
# Exception gdal 21114.tif
# Received a NULL pointer.
# Exception gdal 21115.tif
# Received a NULL pointer.
# Exception gdal 21116.tif
# Received a NULL pointer.
# Exception gdal 21117.tif
# Received a NULL pointer.
# Exception gdal 21118.tif
# Received a NULL pointer.
# Exception gdal 21119.tif
# Received a NULL pointer.
# Exception gdal 21120.tif
# Received a NULL pointer.
# Exception gdal 21121.tif
# Received a NULL pointer.
# Exception gdal 21122.tif
# Received a NULL pointer.
# Exception gdal 21123.tif
# Received a NULL pointer.
# Exception gdal 21124.tif
# Received a NULL pointer.
# Exception gdal 21125.tif
# Received a NULL pointer.
# Exception gdal 21564.tif
# Received a NULL pointer.
# Exception gdal 21566.tif
# Received a NULL pointer.
# File 22001.tif
# Exception gdal 22707.tif
# Received a NULL pointer.
# File 23001.tif
# Exception gdal 23057.tif
# Received a NULL pointer.
# Exception gdal 23058.tif
# Received a NULL pointer.
# Exception gdal 23059.tif
# Received a NULL pointer.
# Exception gdal 23060.tif
# Received a NULL pointer.
# Exception gdal 23061.tif
# Received a NULL pointer.
# Exception gdal 23062.tif
# Received a NULL pointer.
# Exception gdal 23063.tif
# Received a NULL pointer.
# Exception gdal 23064.tif
# Received a NULL pointer.
# Exception gdal 23065.tif
# Received a NULL pointer.
# Exception gdal 23066.tif
# Received a NULL pointer.
# Exception gdal 23067.tif
# Received a NULL pointer.
# Exception gdal 23068.tif
# Received a NULL pointer.
# Exception gdal 23069.tif
# Received a NULL pointer.
# Exception gdal 23070.tif
# Received a NULL pointer.
# Exception gdal 23071.tif
# Received a NULL pointer.
# Exception gdal 23072.tif
# Received a NULL pointer.
# Exception gdal 23073.tif
# Received a NULL pointer.
# Exception gdal 23074.tif
# Received a NULL pointer.
# Exception gdal 23075.tif
# Received a NULL pointer.
# Exception gdal 23076.tif
# Received a NULL pointer.
# Exception gdal 23078.tif
# Received a NULL pointer.
# Exception gdal 23093.tif
# Received a NULL pointer.
# Exception gdal 23319.tif
# Received a NULL pointer.
# Exception gdal 23326.tif
# Received a NULL pointer.
# Exception gdal 23329.tif
# Received a NULL pointer.
# Exception gdal 23330.tif
# Received a NULL pointer.
# Exception gdal 23331.tif
# Received a NULL pointer.
# Exception gdal 23332.tif
# Received a NULL pointer.
# Exception gdal 23334.tif
# Received a NULL pointer.
# Exception gdal 23335.tif
# Received a NULL pointer.
# Exception gdal 23336.tif
# Received a NULL pointer.
# Exception gdal 23337.tif
# Received a NULL pointer.
# Exception gdal 23338.tif
# Received a NULL pointer.
# Exception gdal 23452.tif
# Received a NULL pointer.
# Exception gdal 23454.tif
# Received a NULL pointer.
# Exception gdal 23456.tif
# Received a NULL pointer.
# Exception gdal 23457.tif
# Received a NULL pointer.
# Exception gdal 23458.tif
# Received a NULL pointer.
# Exception gdal 23461.tif
# Received a NULL pointer.
# Exception gdal 23465.tif
# Received a NULL pointer.
# Exception gdal 23466.tif
# Received a NULL pointer.
# Exception gdal 23467.tif
# Received a NULL pointer.
# Exception gdal 23468.tif
# Received a NULL pointer.
# Exception gdal 23469.tif
# Received a NULL pointer.
# Exception gdal 23471.tif
# Received a NULL pointer.
# File 24001.tif
# Exception gdal 24286.tif
# Received a NULL pointer.
# File 25001.tif
# Exception gdal 25151.tif
# Received a NULL pointer.
# Exception gdal 25164.tif
# Received a NULL pointer.
# File 26001.tif
# Exception gdal 26950.tif
# Received a NULL pointer.
# Exception gdal 26951.tif
# Received a NULL pointer.
# Exception gdal 26952.tif
# Received a NULL pointer.
# Exception gdal 26953.tif
# Received a NULL pointer.
# Exception gdal 26954.tif
# Received a NULL pointer.
# Exception gdal 26955.tif
# Received a NULL pointer.
# Exception gdal 26956.tif
# Received a NULL pointer.
# Exception gdal 26957.tif
# Received a NULL pointer.
# Exception gdal 26958.tif
# Received a NULL pointer.
# Exception gdal 26959.tif
# Received a NULL pointer.
# Exception gdal 26960.tif
# Received a NULL pointer.
# Exception gdal 26961.tif
# Received a NULL pointer.
# Exception gdal 26962.tif
# Received a NULL pointer.
# Exception gdal 26963.tif
# Received a NULL pointer.
# Exception gdal 26964.tif
# Received a NULL pointer.
# Exception gdal 26965.tif
# Received a NULL pointer.
# Exception gdal 26966.tif
# Received a NULL pointer.
# Exception gdal 26967.tif
# Received a NULL pointer.
# Exception gdal 26968.tif
# Received a NULL pointer.
# Exception gdal 26969.tif
# Received a NULL pointer.
# Exception gdal 26970.tif
# Received a NULL pointer.
# Exception gdal 26971.tif
# Received a NULL pointer.
# Exception gdal 26972.tif
# Received a NULL pointer.
# Exception gdal 26973.tif
# Received a NULL pointer.
# Exception gdal 26974.tif
# Received a NULL pointer.
# Exception gdal 26975.tif
# Received a NULL pointer.
# Exception gdal 26976.tif
# Received a NULL pointer.
# Exception gdal 26977.tif
# Received a NULL pointer.
# Exception gdal 26978.tif
# Received a NULL pointer.
# Exception gdal 26979.tif
# Received a NULL pointer.
# Exception gdal 26980.tif
# Received a NULL pointer.
# Exception gdal 26981.tif
# Received a NULL pointer.
# Exception gdal 26982.tif
# Received a NULL pointer.
# Exception gdal 26983.tif
# Received a NULL pointer.
# Exception gdal 26984.tif
# Received a NULL pointer.
# Exception gdal 26985.tif
# Received a NULL pointer.
# Exception gdal 26986.tif
# Received a NULL pointer.
# Exception gdal 26987.tif
# Received a NULL pointer.
# Exception gdal 26988.tif
# Received a NULL pointer.
# Exception gdal 26989.tif
# Received a NULL pointer.
# Exception gdal 26990.tif
# Received a NULL pointer.
# Exception gdal 26991.tif
# Received a NULL pointer.
# Exception gdal 26992.tif
# Received a NULL pointer.
# Exception gdal 26993.tif
# Received a NULL pointer.
# Exception gdal 26994.tif
# Received a NULL pointer.
# Exception gdal 26995.tif
# Received a NULL pointer.
# Exception gdal 26996.tif
# Received a NULL pointer.
# Exception gdal 26997.tif
# Received a NULL pointer.
# Exception gdal 26998.tif
# Received a NULL pointer.
# Exception gdal 26999.tif
# Received a NULL pointer.
# Exception gdal 27000.tif
# Received a NULL pointer.
# File 27001.tif
# Exception gdal 27001.tif
# Received a NULL pointer.
# Exception gdal 27002.tif
# Received a NULL pointer.
# Exception gdal 27003.tif
# Received a NULL pointer.
# Exception gdal 27004.tif
# Received a NULL pointer.
# Exception gdal 27005.tif
# Received a NULL pointer.
# Exception gdal 27006.tif
# Received a NULL pointer.
# Exception gdal 27007.tif
# Received a NULL pointer.
# Exception gdal 27008.tif
# Received a NULL pointer.
# Exception gdal 27009.tif
# Received a NULL pointer.
# Exception gdal 27010.tif
# Received a NULL pointer.
# Exception gdal 27011.tif
# Received a NULL pointer.
# Exception gdal 27012.tif
# Received a NULL pointer.
# Exception gdal 27013.tif
# Received a NULL pointer.
# Exception gdal 27014.tif
# Received a NULL pointer.
# Exception gdal 27015.tif
# Received a NULL pointer.
# Exception gdal 27016.tif
# Received a NULL pointer.
# Exception gdal 27017.tif
# Received a NULL pointer.
# Exception gdal 27018.tif
# Received a NULL pointer.
# Exception gdal 27019.tif
# Received a NULL pointer.
# Exception gdal 27020.tif
# Received a NULL pointer.
# Exception gdal 27041.tif
# Received a NULL pointer.
# Exception gdal 27042.tif
# Received a NULL pointer.
# Exception gdal 27043.tif
# Received a NULL pointer.
# Exception gdal 27044.tif
# Received a NULL pointer.
# Exception gdal 27045.tif
# Received a NULL pointer.
# Exception gdal 27046.tif
# Received a NULL pointer.
# Exception gdal 27047.tif
# Received a NULL pointer.
# Exception gdal 27048.tif
# Received a NULL pointer.
# Exception gdal 27049.tif
# Received a NULL pointer.
# Exception gdal 27050.tif
# Received a NULL pointer.
# Exception gdal 27051.tif
# Received a NULL pointer.
# Exception gdal 27052.tif
# Received a NULL pointer.
# Exception gdal 27064.tif
# Received a NULL pointer.
# Exception gdal 27065.tif
# Received a NULL pointer.
# Exception gdal 27066.tif
# Received a NULL pointer.
# Exception gdal 27067.tif
# Received a NULL pointer.
# Exception gdal 27068.tif
# Received a NULL pointer.
# Exception gdal 27069.tif
# Received a NULL pointer.
# Exception gdal 27070.tif
# Received a NULL pointer.
# Exception gdal 27076.tif
# Received a NULL pointer.
# Exception gdal 27077.tif
# Received a NULL pointer.
# Exception gdal 27078.tif
# Received a NULL pointer.
# Exception gdal 27079.tif
# Received a NULL pointer.
# Exception gdal 27080.tif
# Received a NULL pointer.
# Exception gdal 27081.tif
# Received a NULL pointer.
# Exception gdal 27082.tif
# Received a NULL pointer.
# Exception gdal 27083.tif
# Received a NULL pointer.
# Exception gdal 27084.tif
# Received a NULL pointer.
# File 28001.tif
# Exception gdal 28620.tif
# Received a NULL pointer.
# Exception gdal 28621.tif
# Received a NULL pointer.
# Exception gdal 28622.tif
# Received a NULL pointer.
# Exception gdal 28623.tif
# Received a NULL pointer.
# Exception gdal 28624.tif
# Received a NULL pointer.
# Exception gdal 28625.tif
# Received a NULL pointer.
# Exception gdal 28626.tif
# Received a NULL pointer.
# Exception gdal 28627.tif
# Received a NULL pointer.
# Exception gdal 28628.tif
# Received a NULL pointer.
# Exception gdal 28629.tif
# Received a NULL pointer.
# Exception gdal 28630.tif
# Received a NULL pointer.
# Exception gdal 28631.tif
# Received a NULL pointer.
# Exception gdal 28632.tif
# Received a NULL pointer.
# Exception gdal 28633.tif
# Received a NULL pointer.
# Exception gdal 28634.tif
# Received a NULL pointer.
# Exception gdal 28635.tif
# Received a NULL pointer.
# Exception gdal 28636.tif
# Received a NULL pointer.
# Exception gdal 28637.tif
# Received a NULL pointer.
# Exception gdal 28638.tif
# Received a NULL pointer.
# Exception gdal 28639.tif
# Received a NULL pointer.
# Exception gdal 28640.tif
# Received a NULL pointer.
# Exception gdal 28641.tif
# Received a NULL pointer.
# Exception gdal 28642.tif
# Received a NULL pointer.
# Exception gdal 28643.tif
# Received a NULL pointer.
# Exception gdal 28644.tif
# Received a NULL pointer.
# Exception gdal 28645.tif
# Received a NULL pointer.
# Exception gdal 28646.tif
# Received a NULL pointer.
# Exception gdal 28647.tif
# Received a NULL pointer.
# Exception gdal 28648.tif
# Received a NULL pointer.
# Exception gdal 28649.tif
# Received a NULL pointer.
# Exception gdal 28650.tif
# Received a NULL pointer.
# Exception gdal 28651.tif
# Received a NULL pointer.
# Exception gdal 28652.tif
# Received a NULL pointer.
# Exception gdal 28653.tif
# Received a NULL pointer.
# Exception gdal 28654.tif
# Received a NULL pointer.
# Exception gdal 28655.tif
# Received a NULL pointer.
# Exception gdal 28656.tif
# Received a NULL pointer.
# Exception gdal 28657.tif
# Received a NULL pointer.
# Exception gdal 28658.tif
# Received a NULL pointer.
# Exception gdal 28659.tif
# Received a NULL pointer.
# Exception gdal 28660.tif
# Received a NULL pointer.
# Exception gdal 28661.tif
# Received a NULL pointer.
# Exception gdal 28662.tif
# Received a NULL pointer.
# Exception gdal 28663.tif
# Received a NULL pointer.
# Exception gdal 28664.tif
# Received a NULL pointer.
# Exception gdal 28665.tif
# Received a NULL pointer.
# Exception gdal 28666.tif
# Received a NULL pointer.
# Exception gdal 28667.tif
# Received a NULL pointer.
# Exception gdal 28668.tif
# Received a NULL pointer.
# Exception gdal 28669.tif
# Received a NULL pointer.
# Exception gdal 28670.tif
# Received a NULL pointer.
# Exception gdal 28671.tif
# Received a NULL pointer.
# Exception gdal 28672.tif
# Received a NULL pointer.
# Exception gdal 28673.tif
# Received a NULL pointer.
# Exception gdal 28674.tif
# Received a NULL pointer.
# Exception gdal 28675.tif
# Received a NULL pointer.
# Exception gdal 28676.tif
# Received a NULL pointer.
# Exception gdal 28677.tif
# Received a NULL pointer.
# Exception gdal 28678.tif
# Received a NULL pointer.
# Exception gdal 28679.tif
# Received a NULL pointer.
# Exception gdal 28680.tif
# Received a NULL pointer.
# File 29001.tif
# Exception gdal 29261.tif
# Received a NULL pointer.
# Exception gdal 29262.tif
# Received a NULL pointer.
# Exception gdal 29263.tif
# Received a NULL pointer.
# Exception gdal 29264.tif
# Received a NULL pointer.
# Exception gdal 29268.tif
# Received a NULL pointer.
# Exception gdal 29269.tif
# Received a NULL pointer.
# Exception gdal 29270.tif
# Received a NULL pointer.
# Exception gdal 29271.tif
# Received a NULL pointer.
# Exception gdal 29272.tif
# Received a NULL pointer.
# Exception gdal 29273.tif
# Received a NULL pointer.
# Exception gdal 29274.tif
# Received a NULL pointer.
# Exception gdal 29276.tif
# Received a NULL pointer.
# Exception gdal 29279.tif
# Received a NULL pointer.
# Exception gdal 29288.tif
# Received a NULL pointer.
# File 30001.tif
# File 31001.tif
# File 32001.tif
# Exception gdal 32273.tif
# Received a NULL pointer.
# Exception gdal 32275.tif
# Received a NULL pointer.
# Exception gdal 32278.tif
# Received a NULL pointer.
# Exception gdal 32279.tif
# Received a NULL pointer.
# Exception gdal 32291.tif
# Received a NULL pointer.
# Exception gdal 32294.tif
# Received a NULL pointer.
# Exception gdal 32296.tif
# Received a NULL pointer.
# Exception gdal 32298.tif
# Received a NULL pointer.
# Exception gdal 32301.tif
# Received a NULL pointer.
# Exception gdal 32310.tif
# Received a NULL pointer.
# Exception gdal 32311.tif
# Received a NULL pointer.
# Exception gdal 32312.tif
# Received a NULL pointer.
# Exception gdal 32313.tif
# Received a NULL pointer.
# Exception gdal 32314.tif
# Received a NULL pointer.
# Exception gdal 32315.tif
# Received a NULL pointer.
# Exception gdal 32322.tif
# Received a NULL pointer.
# Exception gdal 32323.tif
# Received a NULL pointer.
# Exception gdal 32337.tif
# Received a NULL pointer.
# Exception gdal 32338.tif
# Received a NULL pointer.
# Exception gdal 32339.tif
# Received a NULL pointer.
# Exception gdal 32340.tif
# Received a NULL pointer.
# Exception gdal 32341.tif
# Received a NULL pointer.
# Exception gdal 32342.tif
# Received a NULL pointer.
# Exception gdal 32343.tif
# Received a NULL pointer.
# Exception gdal 32344.tif
# Received a NULL pointer.
# Exception gdal 32345.tif
# Received a NULL pointer.
# Exception gdal 32346.tif
# Received a NULL pointer.
# Exception gdal 32347.tif
# Received a NULL pointer.
# Exception gdal 32348.tif
# Received a NULL pointer.
# Exception gdal 32349.tif
# Received a NULL pointer.
# Exception gdal 32350.tif
# Received a NULL pointer.
# Exception gdal 32351.tif
# Received a NULL pointer.
# Exception gdal 32352.tif
# Received a NULL pointer.
# Exception gdal 32353.tif
# Received a NULL pointer.
# Exception gdal 32354.tif
# Received a NULL pointer.
# Exception gdal 32367.tif
# Received a NULL pointer.
# Exception gdal 32368.tif
# Received a NULL pointer.
# Exception gdal 32369.tif
# Received a NULL pointer.
# Exception gdal 32458.tif
# Received a NULL pointer.
# Exception gdal 32459.tif
# Received a NULL pointer.
# Exception gdal 32460.tif
# Received a NULL pointer.
# Exception gdal 32461.tif
# Received a NULL pointer.
# Exception gdal 32462.tif
# Received a NULL pointer.
# Exception gdal 32463.tif
# Received a NULL pointer.
# Exception gdal 32464.tif
# Received a NULL pointer.
# Exception gdal 32465.tif
# Received a NULL pointer.
# Exception gdal 32494.tif
# Received a NULL pointer.
# Exception gdal 32501.tif
# Received a NULL pointer.
# Exception gdal 32506.tif
# Received a NULL pointer.
# Exception gdal 32526.tif
# Received a NULL pointer.
# Exception gdal 32532.tif
# Received a NULL pointer.
# Exception gdal 32543.tif
# Received a NULL pointer.
# Exception gdal 32554.tif
# Received a NULL pointer.
# Exception gdal 32560.tif
# Received a NULL pointer.
# Exception gdal 32567.tif
# Received a NULL pointer.
# Exception gdal 32583.tif
# Received a NULL pointer.
# Exception gdal 32593.tif
# Received a NULL pointer.
# Exception gdal 32600.tif
# Received a NULL pointer.
# File 33001.tif
# File 34001.tif
# Exception gdal 34096.tif
# Received a NULL pointer.
# Exception gdal 34101.tif
# Received a NULL pointer.
# Exception gdal 34103.tif
# Received a NULL pointer.
# Exception gdal 34105.tif
# Received a NULL pointer.
# Exception gdal 34114.tif
# Received a NULL pointer.
# Exception gdal 34116.tif
# Received a NULL pointer.
# Exception gdal 34118.tif
# Received a NULL pointer.
# Exception gdal 34119.tif
# Received a NULL pointer.
# Exception gdal 34122.tif
# Received a NULL pointer.
# Exception gdal 34123.tif
# Received a NULL pointer.
# Exception gdal 34125.tif
# Received a NULL pointer.
# Exception gdal 34179.tif
# Received a NULL pointer.
# Exception gdal 34183.tif
# Received a NULL pointer.
# Exception gdal 34188.tif
# Received a NULL pointer.
# Exception gdal 34192.tif
# Received a NULL pointer.
# Exception gdal 34193.tif
# Received a NULL pointer.
# Exception gdal 34199.tif
# Received a NULL pointer.
# Exception gdal 34202.tif
# Received a NULL pointer.
# Exception gdal 34206.tif
# Received a NULL pointer.
# Exception gdal 34210.tif
# Received a NULL pointer.
# Exception gdal 34211.tif
# Received a NULL pointer.
# Exception gdal 34226.tif
# Received a NULL pointer.
# Exception gdal 34227.tif
# Received a NULL pointer.
# Exception gdal 34229.tif
# Received a NULL pointer.
# Exception gdal 34230.tif
# Received a NULL pointer.
# Exception gdal 34231.tif
# Received a NULL pointer.
# Exception gdal 34232.tif
# Received a NULL pointer.
# Exception gdal 34233.tif
# Received a NULL pointer.
# Exception gdal 34234.tif
# Received a NULL pointer.
# Exception gdal 34236.tif
# Received a NULL pointer.
# Exception gdal 34237.tif
# Received a NULL pointer.
# Exception gdal 34239.tif
# Received a NULL pointer.
# Exception gdal 34241.tif
# Received a NULL pointer.
# Exception gdal 34242.tif
# Received a NULL pointer.
# Exception gdal 34244.tif
# Received a NULL pointer.
# Exception gdal 34245.tif
# Received a NULL pointer.
# Exception gdal 34246.tif
# Received a NULL pointer.
# Exception gdal 34247.tif
# Received a NULL pointer.
# Exception gdal 34248.tif
# Received a NULL pointer.
# Exception gdal 34249.tif
# Received a NULL pointer.
# Exception gdal 34251.tif
# Received a NULL pointer.
# Exception gdal 34252.tif
# Received a NULL pointer.
# Exception gdal 34254.tif
# Received a NULL pointer.
# Exception gdal 34256.tif
# Received a NULL pointer.
# Exception gdal 34258.tif
# Received a NULL pointer.
# Exception gdal 34259.tif
# Received a NULL pointer.
# Exception gdal 34260.tif
# Received a NULL pointer.
# Exception gdal 34261.tif
# Received a NULL pointer.
# Exception gdal 34262.tif
# Received a NULL pointer.
# Exception gdal 34263.tif
# Received a NULL pointer.
# Exception gdal 34264.tif
# Received a NULL pointer.
# Exception gdal 34267.tif
# Received a NULL pointer.
# Exception gdal 34268.tif
# Received a NULL pointer.
# Exception gdal 34270.tif
# Received a NULL pointer.
# Exception gdal 34272.tif
# Received a NULL pointer.
# Exception gdal 34273.tif
# Received a NULL pointer.
# Exception gdal 34274.tif
# Received a NULL pointer.
# Exception gdal 34275.tif
# Received a NULL pointer.
# Exception gdal 34276.tif
# Received a NULL pointer.
# Exception gdal 34277.tif
# Received a NULL pointer.
# Exception gdal 34278.tif
# Received a NULL pointer.
# Exception gdal 34279.tif
# Received a NULL pointer.
# Exception gdal 34281.tif
# Received a NULL pointer.
# Exception gdal 34282.tif
# Received a NULL pointer.
# Exception gdal 34285.tif
# Received a NULL pointer.
# Exception gdal 34287.tif
# Received a NULL pointer.
# Exception gdal 34288.tif
# Received a NULL pointer.
# Exception gdal 34289.tif
# Received a NULL pointer.
# Exception gdal 34290.tif
# Received a NULL pointer.
# Exception gdal 34291.tif
# Received a NULL pointer.
# Exception gdal 34293.tif
# Received a NULL pointer.
# Exception gdal 34294.tif
# Received a NULL pointer.
# Exception gdal 34297.tif
# Received a NULL pointer.
# Exception gdal 34300.tif
# Received a NULL pointer.
# Exception gdal 34301.tif
# Received a NULL pointer.
# Exception gdal 34302.tif
# Received a NULL pointer.
# Exception gdal 34303.tif
# Received a NULL pointer.
# Exception gdal 34306.tif
# Received a NULL pointer.
# Exception gdal 34309.tif
# Received a NULL pointer.
# Exception gdal 34312.tif
# Received a NULL pointer.
# Exception gdal 34313.tif
# Received a NULL pointer.
# Exception gdal 34314.tif
# Received a NULL pointer.
# Exception gdal 34315.tif
# Received a NULL pointer.
# Exception gdal 34317.tif
# Received a NULL pointer.
# Exception gdal 34319.tif
# Received a NULL pointer.
# Exception gdal 34320.tif
# Received a NULL pointer.
# Exception gdal 34321.tif
# Received a NULL pointer.
# Exception gdal 34323.tif
# Received a NULL pointer.
# Exception gdal 34324.tif
# Received a NULL pointer.
# Exception gdal 34325.tif
# Received a NULL pointer.
# Exception gdal 34327.tif
# Received a NULL pointer.
# Exception gdal 34329.tif
# Received a NULL pointer.
# Exception gdal 34332.tif
# Received a NULL pointer.
# Exception gdal 34333.tif
# Received a NULL pointer.
# Exception gdal 34334.tif
# Received a NULL pointer.
# Exception gdal 34335.tif
# Received a NULL pointer.
# Exception gdal 34336.tif
# Received a NULL pointer.
# Exception gdal 34337.tif
# Received a NULL pointer.
# Exception gdal 34338.tif
# Received a NULL pointer.
# Exception gdal 34340.tif
# Received a NULL pointer.
# Exception gdal 34341.tif
# Received a NULL pointer.
# Exception gdal 34342.tif
# Received a NULL pointer.
# Exception gdal 34345.tif
# Received a NULL pointer.
# Exception gdal 34346.tif
# Received a NULL pointer.
# Exception gdal 34347.tif
# Received a NULL pointer.
# Exception gdal 34348.tif
# Received a NULL pointer.
# Exception gdal 34349.tif
# Received a NULL pointer.
# Exception gdal 34350.tif
# Received a NULL pointer.
# Exception gdal 34351.tif
# Received a NULL pointer.
# Exception gdal 34352.tif
# Received a NULL pointer.
# Exception gdal 34354.tif
# Received a NULL pointer.
# Exception gdal 34355.tif
# Received a NULL pointer.
# Exception gdal 34357.tif
# Received a NULL pointer.
# Exception gdal 34359.tif
# Received a NULL pointer.
# Exception gdal 34360.tif
# Received a NULL pointer.
# Exception gdal 34361.tif
# Received a NULL pointer.
# Exception gdal 34362.tif
# Received a NULL pointer.
# Exception gdal 34363.tif
# Received a NULL pointer.
# Exception gdal 34364.tif
# Received a NULL pointer.
# Exception gdal 34365.tif
# Received a NULL pointer.
# Exception gdal 34367.tif
# Received a NULL pointer.
# Exception gdal 34368.tif
# Received a NULL pointer.
# Exception gdal 34370.tif
# Received a NULL pointer.
# Exception gdal 34372.tif
# Received a NULL pointer.
# Exception gdal 34374.tif
# Received a NULL pointer.
# Exception gdal 34375.tif
# Received a NULL pointer.
# Exception gdal 34376.tif
# Received a NULL pointer.
# Exception gdal 34379.tif
# Received a NULL pointer.
# Exception gdal 34381.tif
# Received a NULL pointer.
# Exception gdal 34384.tif
# Received a NULL pointer.
# Exception gdal 34385.tif
# Received a NULL pointer.
# File 35001.tif
# Exception gdal 35600.tif
# Received a NULL pointer.
# File 36001.tif
# File 37001.tif
# Exception gdal 37035.tif
# Received a NULL pointer.
# Exception gdal 37038.tif
# Received a NULL pointer.
# Exception gdal 37039.tif
# Received a NULL pointer.
# Exception gdal 37040.tif
# Received a NULL pointer.
# Exception gdal 37063.tif
# Received a NULL pointer.
# Exception gdal 37065.tif
# Received a NULL pointer.
# Exception gdal 37068.tif
# Received a NULL pointer.
# Exception gdal 37070.tif
# Received a NULL pointer.
# Exception gdal 37071.tif
# Received a NULL pointer.
# Exception gdal 37072.tif
# Received a NULL pointer.
# Exception gdal 37073.tif
# Received a NULL pointer.
# Exception gdal 37074.tif
# Received a NULL pointer.
# Exception gdal 37075.tif
# Received a NULL pointer.
# Exception gdal 37077.tif
# Received a NULL pointer.
# Exception gdal 37078.tif
# Received a NULL pointer.
# Exception gdal 37079.tif
# Received a NULL pointer.
# Exception gdal 37737.tif
# Received a NULL pointer.
# Exception gdal 37747.tif
# Received a NULL pointer.
# Exception gdal 37751.tif
# Received a NULL pointer.
# Exception gdal 37787.tif
# Received a NULL pointer.
# Exception gdal 37805.tif
# Received a NULL pointer.
# Exception gdal 37806.tif
# Received a NULL pointer.
# File 38001.tif
# Exception gdal 38400.tif
# Received a NULL pointer.
# Exception gdal 38401.tif
# Received a NULL pointer.
# Exception gdal 38402.tif
# Received a NULL pointer.
# Exception gdal 38403.tif
# Received a NULL pointer.
# Exception gdal 38404.tif
# Received a NULL pointer.
# Exception gdal 38405.tif
# Received a NULL pointer.
# Exception gdal 38406.tif
# Received a NULL pointer.
# Exception gdal 38407.tif
# Received a NULL pointer.
# Exception gdal 38408.tif
# Received a NULL pointer.
# Exception gdal 38409.tif
# Received a NULL pointer.
# Exception gdal 38410.tif
# Received a NULL pointer.
# Exception gdal 38411.tif
# Received a NULL pointer.
# Exception gdal 38412.tif
# Received a NULL pointer.
# Exception gdal 38413.tif
# Received a NULL pointer.
# Exception gdal 38414.tif
# Received a NULL pointer.
# Exception gdal 38415.tif
# Received a NULL pointer.
# Exception gdal 38416.tif
# Received a NULL pointer.
# Exception gdal 38417.tif
# Received a NULL pointer.
# Exception gdal 38418.tif
# Received a NULL pointer.
# Exception gdal 38419.tif
# Received a NULL pointer.
# Exception gdal 38420.tif
# Received a NULL pointer.
# Exception gdal 38421.tif
# Received a NULL pointer.
# Exception gdal 38422.tif
# Received a NULL pointer.
# Exception gdal 38423.tif
# Received a NULL pointer.
# Exception gdal 38424.tif
# Received a NULL pointer.
# Exception gdal 38425.tif
# Received a NULL pointer.
# Exception gdal 38426.tif
# Received a NULL pointer.
# File 39001.tif
# Exception gdal 39369.tif
# Received a NULL pointer.
# Exception gdal 39370.tif
# Received a NULL pointer.
# Exception gdal 39371.tif
# Received a NULL pointer.
# Exception gdal 39372.tif
# Received a NULL pointer.
# Exception gdal 39373.tif
# Received a NULL pointer.
# Exception gdal 39388.tif
# Received a NULL pointer.
# Exception gdal 39389.tif
# Received a NULL pointer.
# Exception gdal 39392.tif
# Received a NULL pointer.
# Exception gdal 39393.tif
# Received a NULL pointer.
# Exception gdal 39394.tif
# Received a NULL pointer.
# File 40001.tif
# File 41001.tif
# Exception gdal 41468.tif
# Received a NULL pointer.
# Exception gdal 41470.tif
# Received a NULL pointer.
# Exception gdal 41472.tif
# Received a NULL pointer.
# Exception gdal 41473.tif
# Received a NULL pointer.
# Exception gdal 41481.tif
# Received a NULL pointer.
# Exception gdal 41482.tif
# Received a NULL pointer.
# Exception gdal 41484.tif
# Received a NULL pointer.
# Exception gdal 41485.tif
# Received a NULL pointer.
# Exception gdal 41487.tif
# Received a NULL pointer.
# Exception gdal 41489.tif
# Received a NULL pointer.
# Exception gdal 41490.tif
# Received a NULL pointer.
# File 42001.tif
# Exception gdal 42673.tif
# Received a NULL pointer.
# Exception gdal 42674.tif
# Received a NULL pointer.
# Exception gdal 42675.tif
# Received a NULL pointer.
# Exception gdal 42676.tif
# Received a NULL pointer.
# Exception gdal 42677.tif
# Received a NULL pointer.
# Exception gdal 42702.tif
# Received a NULL pointer.
# Exception gdal 42703.tif
# Received a NULL pointer.
# Exception gdal 42704.tif
# Received a NULL pointer.
# Exception gdal 42705.tif
# Received a NULL pointer.
# Exception gdal 42706.tif
# Received a NULL pointer.
# Exception gdal 42707.tif
# Received a NULL pointer.
# Exception gdal 42708.tif
# Received a NULL pointer.
# Exception gdal 42709.tif
# Received a NULL pointer.
# Exception gdal 42710.tif
# Received a NULL pointer.
# Exception gdal 42711.tif
# Received a NULL pointer.
# Exception gdal 42712.tif
# Received a NULL pointer.
# Exception gdal 42732.tif
# Received a NULL pointer.
# Exception gdal 42733.tif
# Received a NULL pointer.
# Exception gdal 42740.tif
# Received a NULL pointer.
# Exception gdal 42741.tif
# Received a NULL pointer.
# ...
# Exception gdal 7008.tif
# Received a NULL pointer.
# Exception gdal 7055.tif
# Received a NULL pointer.
# Exception gdal 7069.tif
# Received a NULL pointer.
# Exception gdal 7144.tif
# Received a NULL pointer.
# Exception gdal 7150.tif
# Received a NULL pointer.
# Exception gdal 7163.tif
# Received a NULL pointer.
# Exception gdal 7175.tif
# Received a NULL pointer.
# Exception gdal 7189.tif
# Received a NULL pointer.
# Exception gdal 7195.tif
# Received a NULL pointer.
# Exception gdal 7201.tif
# Received a NULL pointer.
# Exception gdal 7222.tif
# Received a NULL pointer.
# Exception gdal 7240.tif
# Received a NULL pointer.
# Exception gdal 7261.tif
# Received a NULL pointer.
# Exception gdal 7284.tif
# Received a NULL pointer.
# Exception gdal 7293.tif
# Received a NULL pointer.
# Exception gdal 7354.tif
# Received a NULL pointer.
# Exception gdal 7398.tif
# Received a NULL pointer.
# Exception gdal 7411.tif
# Received a NULL pointer.
# Exception gdal 7464.tif
# Received a NULL pointer.
# Exception gdal 7467.tif
# Received a NULL pointer.
# Exception gdal 7468.tif
# Received a NULL pointer.
# Exception gdal 7478.tif
# Received a NULL pointer.
# Exception gdal 7524.tif
# Received a NULL pointer.
# Exception gdal 7548.tif
# Received a NULL pointer.
# Exception gdal 7551.tif
# Received a NULL pointer.
# Exception gdal 7566.tif
# Received a NULL pointer.
# Exception gdal 7569.tif
# Received a NULL pointer.
# Exception gdal 7580.tif
# Received a NULL pointer.
# Exception gdal 7581.tif
# Received a NULL pointer.
# Exception gdal 7604.tif
# Received a NULL pointer.
# Exception gdal 7625.tif
# Received a NULL pointer.
# Exception gdal 7638.tif
# Received a NULL pointer.
# Exception gdal 7680.tif
# Received a NULL pointer.
# Exception gdal 7702.tif
# Received a NULL pointer.
# Exception gdal 7734.tif
# Received a NULL pointer.
# Exception gdal 7738.tif
# Received a NULL pointer.
# Exception gdal 7783.tif
# Received a NULL pointer.
# Exception gdal 7806.tif
# Received a NULL pointer.
# Exception gdal 7807.tif
# Received a NULL pointer.
# Exception gdal 7813.tif
# Received a NULL pointer.
# Exception gdal 7832.tif
# Received a NULL pointer.
# Exception gdal 7844.tif
# Received a NULL pointer.
# Exception gdal 7848.tif
# Received a NULL pointer.
# Exception gdal 7939.tif
# Received a NULL pointer.
# Exception gdal 7953.tif
# Received a NULL pointer.
# Exception gdal 7975.tif
# Received a NULL pointer.
# File 8001.tif
# Exception gdal 8001.tif
# Received a NULL pointer.
# Exception gdal 8006.tif
# Received a NULL pointer.
# Exception gdal 8012.tif
# Received a NULL pointer.
# Exception gdal 8045.tif
# Received a NULL pointer.
# Exception gdal 8046.tif
# Received a NULL pointer.
# Exception gdal 8102.tif
# Received a NULL pointer.
# Exception gdal 8111.tif
# Received a NULL pointer.
# Exception gdal 8144.tif
# Received a NULL pointer.
# Exception gdal 8169.tif
# Received a NULL pointer.
# Exception gdal 8170.tif
# Received a NULL pointer.
# Exception gdal 8204.tif
# Received a NULL pointer.
# Exception gdal 8209.tif
# Received a NULL pointer.
# Exception gdal 8270.tif
# Received a NULL pointer.
# Exception gdal 8305.tif
# Received a NULL pointer.
# Exception gdal 8337.tif
# Received a NULL pointer.
# Exception gdal 8351.tif
# Received a NULL pointer.
# Exception gdal 8356.tif
# Received a NULL pointer.
# Exception gdal 8418.tif
# Received a NULL pointer.
# Exception gdal 8473.tif
# Received a NULL pointer.
# Exception gdal 8495.tif
# Received a NULL pointer.
# Exception gdal 8506.tif
# Received a NULL pointer.
# Exception gdal 8512.tif
# Received a NULL pointer.
# Exception gdal 8544.tif
# Received a NULL pointer.
# Exception gdal 8550.tif
# Received a NULL pointer.
# Exception gdal 8574.tif
# Received a NULL pointer.
# Exception gdal 8595.tif
# Received a NULL pointer.
# Exception gdal 8598.tif
# Received a NULL pointer.
# Exception gdal 8603.tif
# Received a NULL pointer.
# Exception gdal 8615.tif
# Received a NULL pointer.
# Exception gdal 8652.tif
# Received a NULL pointer.
# Exception gdal 8678.tif
# Received a NULL pointer.
# Exception gdal 8692.tif
# Received a NULL pointer.
# Exception gdal 8697.tif
# Received a NULL pointer.
# Exception gdal 8705.tif
# Received a NULL pointer.
# Exception gdal 8743.tif
# Received a NULL pointer.
# Exception gdal 8784.tif
# Received a NULL pointer.
# Exception gdal 8785.tif
# Received a NULL pointer.
# Exception gdal 8797.tif
# Received a NULL pointer.
# Exception gdal 8804.tif
# Received a NULL pointer.
# Exception gdal 8835.tif
# Received a NULL pointer.
# Exception gdal 8847.tif
# Received a NULL pointer.
# Exception gdal 8866.tif
# Received a NULL pointer.
# Exception gdal 8877.tif
# Received a NULL pointer.
# Exception gdal 8904.tif
# Received a NULL pointer.
# Exception gdal 8912.tif
# Received a NULL pointer.
# Exception gdal 8953.tif
# Received a NULL pointer.
# Exception gdal 8993.tif
# Received a NULL pointer.
# File 9001.tif
# Exception gdal 9001.tif
# Received a NULL pointer.
# Exception gdal 9002.tif
# Received a NULL pointer.
# Exception gdal 9016.tif
# Received a NULL pointer.
# Exception gdal 9020.tif
# Received a NULL pointer.
# Exception gdal 9021.tif
# Received a NULL pointer.
# Exception gdal 9027.tif
# Received a NULL pointer.
# Exception gdal 9033.tif
# Received a NULL pointer.
# Exception gdal 9060.tif
# Received a NULL pointer.
# Exception gdal 9068.tif
# Received a NULL pointer.
# Exception gdal 9132.tif
# Received a NULL pointer.
# Exception gdal 9150.tif
# Received a NULL pointer.
# Exception gdal 9160.tif
# Received a NULL pointer.
# Exception gdal 9206.tif
# Received a NULL pointer.
# Exception gdal 9216.tif
# Received a NULL pointer.
# Exception gdal 9223.tif
# Received a NULL pointer.
# Exception gdal 9232.tif
# Received a NULL pointer.
# Exception gdal 9253.tif
# Received a NULL pointer.
# Exception gdal 9288.tif
# Received a NULL pointer.
# Exception gdal 9308.tif
# Received a NULL pointer.
# Exception gdal 9327.tif
# Received a NULL pointer.
# Exception gdal 9342.tif
# Received a NULL pointer.
# Exception gdal 9356.tif
# Received a NULL pointer.
# Exception gdal 9374.tif
# Received a NULL pointer.
# Exception gdal 9390.tif
# Received a NULL pointer.
# Exception gdal 9406.tif
# Received a NULL pointer.
# Exception gdal 9409.tif
# Received a NULL pointer.
# Exception gdal 9413.tif
# Received a NULL pointer.
# Exception gdal 9439.tif
# Received a NULL pointer.
# Exception gdal 9480.tif
# Received a NULL pointer.
# Exception gdal 9496.tif
# Received a NULL pointer.
# Exception gdal 9511.tif
# Received a NULL pointer.
# Exception gdal 9521.tif
# Received a NULL pointer.
# Exception gdal 9536.tif
# Received a NULL pointer.
# Exception gdal 9547.tif
# Received a NULL pointer.
# Exception gdal 9560.tif
# Received a NULL pointer.
# Exception gdal 9566.tif
# Received a NULL pointer.
# Exception gdal 9580.tif
# Received a NULL pointer.
# Exception gdal 9601.tif
# Received a NULL pointer.
# Exception gdal 9617.tif
# Received a NULL pointer.
# Exception gdal 9700.tif
# Received a NULL pointer.
# Exception gdal 9701.tif
# Received a NULL pointer.
# Exception gdal 9709.tif
# Received a NULL pointer.
# Exception gdal 9727.tif
# Received a NULL pointer.
# Exception gdal 9747.tif
# Received a NULL pointer.
# Exception gdal 9756.tif
# Received a NULL pointer.
# Exception gdal 9773.tif
# Received a NULL pointer.
# Exception gdal 9776.tif
# Received a NULL pointer.
# Exception gdal 9780.tif
# Received a NULL pointer.
# Exception gdal 9787.tif
# Received a NULL pointer.
# Exception gdal 9802.tif
# Received a NULL pointer.
# Exception gdal 9868.tif
# Received a NULL pointer.
# Exception gdal 9869.tif
# Received a NULL pointer.
# Exception gdal 9884.tif
# Received a NULL pointer.
# Exception gdal 9899.tif
# Received a NULL pointer.
# Exception gdal 9996.tif
# Received a NULL pointer.
# File 10001.tif
# Exception gdal 10002.tif
# Received a NULL pointer.
# Exception gdal 10009.tif
# Received a NULL pointer.
# Exception gdal 10020.tif
# Received a NULL pointer.
# Exception gdal 10037.tif
# Received a NULL pointer.
# Exception gdal 10041.tif
# Received a NULL pointer.
# Exception gdal 10074.tif
# Received a NULL pointer.
# Exception gdal 10080.tif
# Received a NULL pointer.
# Exception gdal 10092.tif
# Received a NULL pointer.
# Exception gdal 10094.tif
# Received a NULL pointer.
# Exception gdal 10141.tif
# Received a NULL pointer.
# --------Current country: CA--------
# File 1.tif
# Exception gdal 130.tif
# Received a NULL pointer.
# Exception gdal 131.tif
# Received a NULL pointer.
# Exception gdal 132.tif
# Received a NULL pointer.
# Exception gdal 134.tif
# Received a NULL pointer.
# Exception gdal 155.tif
# Received a NULL pointer.
# Exception gdal 183.tif
# Received a NULL pointer.
# File 1001.tif
# Exception gdal 1133.tif
# Received a NULL pointer.
# Exception gdal 1135.tif
# Received a NULL pointer.
# Exception gdal 1136.tif
# Received a NULL pointer.
# Exception gdal 1139.tif
# Received a NULL pointer.
# Exception gdal 1143.tif
# Received a NULL pointer.
# Exception gdal 1556.tif
# Received a NULL pointer.
# Exception gdal 1557.tif
# Received a NULL pointer.
# Exception gdal 1558.tif
# Received a NULL pointer.
# Exception gdal 1559.tif
# Received a NULL pointer.
# Exception gdal 1560.tif
# Received a NULL pointer.
# Exception gdal 1561.tif
# Received a NULL pointer.
# Exception gdal 1562.tif
# Received a NULL pointer.
# Exception gdal 1563.tif
# Received a NULL pointer.
# Exception gdal 1564.tif
# Received a NULL pointer.
# Exception gdal 1565.tif
# Received a NULL pointer.
# Exception gdal 1566.tif
# Received a NULL pointer.
# Exception gdal 1567.tif
# Received a NULL pointer.
# Exception gdal 1568.tif
# Received a NULL pointer.
# Exception gdal 1569.tif
# Received a NULL pointer.
# Exception gdal 1570.tif
# Received a NULL pointer.
# Exception gdal 1571.tif
# Received a NULL pointer.
# Exception gdal 1572.tif
# Received a NULL pointer.
# Exception gdal 1573.tif
# Received a NULL pointer.
# Exception gdal 1574.tif
# Received a NULL pointer.
# Exception gdal 1575.tif
# Received a NULL pointer.
# Exception gdal 1576.tif
# Received a NULL pointer.
# Exception gdal 1577.tif
# Received a NULL pointer.
# Exception gdal 1578.tif
# Received a NULL pointer.
# Exception gdal 1579.tif
# Received a NULL pointer.
# Exception gdal 1580.tif
# Received a NULL pointer.
# Exception gdal 1581.tif
# Received a NULL pointer.
# Exception gdal 1582.tif
# Received a NULL pointer.
# Exception gdal 1583.tif
# Received a NULL pointer.
# Exception gdal 1584.tif
# Received a NULL pointer.
# Exception gdal 1585.tif
# Received a NULL pointer.
# Exception gdal 1586.tif
# Received a NULL pointer.
# Exception gdal 1587.tif
# Received a NULL pointer.
# Exception gdal 1588.tif
# Received a NULL pointer.
# Exception gdal 1589.tif
# Received a NULL pointer.
# Exception gdal 1590.tif
# Received a NULL pointer.
# Exception gdal 1591.tif
# Received a NULL pointer.
# Exception gdal 1592.tif
# Received a NULL pointer.
# Exception gdal 1593.tif
# Received a NULL pointer.
# Exception gdal 1594.tif
# Received a NULL pointer.
# Exception gdal 1595.tif
# Received a NULL pointer.
# Exception gdal 1596.tif
# Received a NULL pointer.
# Exception gdal 1597.tif
# Received a NULL pointer.
# Exception gdal 1598.tif
# Received a NULL pointer.
# Exception gdal 1599.tif
# Received a NULL pointer.
# Exception gdal 1600.tif
# Received a NULL pointer.
# Exception gdal 1601.tif
# Received a NULL pointer.
# Exception gdal 1602.tif
# Received a NULL pointer.
# Exception gdal 1603.tif
# Received a NULL pointer.
# Exception gdal 1604.tif
# Received a NULL pointer.
# Exception gdal 1605.tif
# Received a NULL pointer.
# Exception gdal 1606.tif
# Received a NULL pointer.
# Exception gdal 1607.tif
# Received a NULL pointer.
# Exception gdal 1608.tif
# Received a NULL pointer.
# Exception gdal 1609.tif
# Received a NULL pointer.
# Exception gdal 1610.tif
# Received a NULL pointer.
# Exception gdal 1611.tif
# Received a NULL pointer.
# Exception gdal 1612.tif
# Received a NULL pointer.
# Exception gdal 1613.tif
# Received a NULL pointer.
# Exception gdal 1614.tif
# Received a NULL pointer.
# Exception gdal 1615.tif
# Received a NULL pointer.
# Exception gdal 1616.tif
# Received a NULL pointer.
# Exception gdal 1617.tif
# Received a NULL pointer.
# Exception gdal 1618.tif
# Received a NULL pointer.
# Exception gdal 1619.tif
# Received a NULL pointer.
# Exception gdal 1620.tif
# Received a NULL pointer.
# Exception gdal 1621.tif
# Received a NULL pointer.
# Exception gdal 1622.tif
# Received a NULL pointer.
# Exception gdal 1623.tif
# Received a NULL pointer.
# Exception gdal 1624.tif
# Received a NULL pointer.
# Exception gdal 1625.tif
# Received a NULL pointer.
# Exception gdal 1626.tif
# Received a NULL pointer.
# Exception gdal 1627.tif
# Received a NULL pointer.
# Exception gdal 1628.tif
# Received a NULL pointer.
# Exception gdal 1629.tif
# Received a NULL pointer.
# Exception gdal 1630.tif
# Received a NULL pointer.
# Exception gdal 1631.tif
# Received a NULL pointer.
# File 2001.tif
# Exception gdal 2349.tif
# Received a NULL pointer.
# Exception gdal 2350.tif
# Received a NULL pointer.
# Exception gdal 2588.tif
# Received a NULL pointer.
# Exception gdal 2589.tif
# Received a NULL pointer.
# Exception gdal 2590.tif
# Received a NULL pointer.
# Exception gdal 2591.tif
# Received a NULL pointer.
# Exception gdal 2592.tif
# Received a NULL pointer.
# Exception gdal 2593.tif
# Received a NULL pointer.
# Exception gdal 2594.tif
# Received a NULL pointer.
# File 3001.tif
# Exception gdal 3928.tif
# Received a NULL pointer.
# Exception gdal 3929.tif
# Received a NULL pointer.
# Exception gdal 3930.tif
# Received a NULL pointer.
# Exception gdal 3931.tif
# Received a NULL pointer.
# Exception gdal 3932.tif
# Received a NULL pointer.
# Exception gdal 3933.tif
# Received a NULL pointer.
# Exception gdal 3934.tif
# Received a NULL pointer.
# Exception gdal 3935.tif
# Received a NULL pointer.
# Exception gdal 3936.tif
# Received a NULL pointer.
# Exception gdal 3937.tif
# Received a NULL pointer.
# Exception gdal 3938.tif
# Received a NULL pointer.
# Exception gdal 3939.tif
# Received a NULL pointer.
# Exception gdal 3940.tif
# Received a NULL pointer.
# Exception gdal 3941.tif
# Received a NULL pointer.
# Exception gdal 3942.tif
# Received a NULL pointer.
# Exception gdal 3943.tif
# Received a NULL pointer.
# Exception gdal 3944.tif
# Received a NULL pointer.
# Exception gdal 3945.tif
# Received a NULL pointer.
# Exception gdal 3946.tif
# Received a NULL pointer.
# File 4001.tif
# Exception gdal 4138.tif
# Received a NULL pointer.
# Exception gdal 4306.tif
# Received a NULL pointer.
# Exception gdal 4970.tif
# Received a NULL pointer.
# Exception gdal 4971.tif
# Received a NULL pointer.
# Exception gdal 4972.tif
# Received a NULL pointer.
# File 5001.tif
# Exception gdal 5075.tif
# Received a NULL pointer.
# Exception gdal 5076.tif
# Received a NULL pointer.
# Exception gdal 5077.tif
# Received a NULL pointer.
# Exception gdal 5246.tif
# Received a NULL pointer.
# Exception gdal 5247.tif
# Received a NULL pointer.
# Exception gdal 5248.tif
# Received a NULL pointer.
# Exception gdal 5249.tif
# Received a NULL pointer.
# Exception gdal 5250.tif
# Received a NULL pointer.
# Exception gdal 5251.tif
# Received a NULL pointer.
# Exception gdal 5253.tif
# Received a NULL pointer.
# Exception gdal 5254.tif
# Received a NULL pointer.
# Exception gdal 5255.tif
# Received a NULL pointer.
# Exception gdal 5257.tif
# Received a NULL pointer.
# Exception gdal 5404.tif
# Received a NULL pointer.
# Exception gdal 5405.tif
# Received a NULL pointer.
# Exception gdal 5406.tif
# Received a NULL pointer.
# Exception gdal 5407.tif
# Received a NULL pointer.
# Exception gdal 5408.tif
# Received a NULL pointer.
# Exception gdal 5409.tif
# Received a NULL pointer.
# Exception gdal 5410.tif
# Received a NULL pointer.
# Exception gdal 5411.tif
# Received a NULL pointer.
# Exception gdal 5412.tif
# Received a NULL pointer.
# Exception gdal 5413.tif
# Received a NULL pointer.
# Exception gdal 5414.tif
# Received a NULL pointer.
# Exception gdal 5512.tif
# Received a NULL pointer.
# Exception gdal 5513.tif
# Received a NULL pointer.
# Exception gdal 5514.tif
# Received a NULL pointer.
# Exception gdal 5515.tif
# Received a NULL pointer.
# Exception gdal 5516.tif
# Received a NULL pointer.
# Exception gdal 5517.tif
# Received a NULL pointer.
# Exception gdal 5518.tif
# Received a NULL pointer.
# Exception gdal 5519.tif
# Received a NULL pointer.
# Exception gdal 5520.tif
# Received a NULL pointer.
# Exception gdal 5521.tif
# Received a NULL pointer.
# Exception gdal 5522.tif
# Received a NULL pointer.
# Exception gdal 5523.tif
# Received a NULL pointer.
# Exception gdal 5524.tif
# Received a NULL pointer.
# Exception gdal 5525.tif
# Received a NULL pointer.
# Exception gdal 5526.tif
# Received a NULL pointer.
# Exception gdal 5527.tif
# Received a NULL pointer.
# Exception gdal 5528.tif
# Received a NULL pointer.
# Exception gdal 5529.tif
# Received a NULL pointer.
# Exception gdal 5530.tif
# Received a NULL pointer.
# Exception gdal 5531.tif
# Received a NULL pointer.
# Exception gdal 5536.tif
# Received a NULL pointer.

# %%
predictions.head()
# Out:
#           lon        lat prediction filenames directory country
# 0   88.698447  43.082907         -1     1.tif                CN
# 1   88.578303  43.062933  0.0231545     2.tif                CN
# 2  118.920395  37.469542     0.9881     3.tif                CN
# 3  115.423369  41.240915   0.999571     4.tif                CN
# 4  115.419332  41.237457   0.999993     5.tif                CN

# %%
predictions.to_csv(fpr.get_param("MIX", "FILE_OSM_TURBINE_LOCATIONS") + "assessment.csv")

# %%
predictions.head()
# Out:
#           lon        lat prediction filenames directory country
# 0   88.698447  43.082907         -1     1.tif                CN
# 1   88.578303  43.062933  0.0231545     2.tif                CN
# 2  118.920395  37.469542     0.9881     3.tif                CN
# 3  115.423369  41.240915   0.999571     4.tif                CN
# 4  115.419332  41.237457   0.999993     5.tif                CN
