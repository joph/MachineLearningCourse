# %%
cd /data/projects/windturbine-identification/MachineLearningCourse
# Out:
# /data/projects/windturbine-identification/MachineLearningCourse

# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Feb 18 13:04:17 2019


@author: jschmidt
"""
import imp
import scripts.windturbines.functions_pattern_recognition as fpr
imp.reload(fpr)

# %load_ext autoreload

# %autoreload 2
# Out:
# Using TensorFlow backend.
# /home/jschmidt/.conda/envs/windturbine-identification/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/jschmidt/.conda/envs/windturbine-identification/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/jschmidt/.conda/envs/windturbine-identification/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# ...

# %% [markdown]
# # Training Phase

# %%
best_models = []

COUNTRY = "US"

# %%
RESOLUTION = 13

#fpr.remove_erroneous_files(COUNTRY, RESOLUTION)
mod = fpr.train_model_res(RESOLUTION, COUNTRY, 100)
best_models.append(mod)
# Out:
# Found 45009 validated image filenames belonging to 2 classes.
# Found 15003 validated image filenames belonging to 2 classes.
# Found 15004 validated image filenames belonging to 2 classes.
# WARNING:tensorflow:From /home/jschmidt/.conda/envs/windturbine-identification/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/jschmidt/.conda/envs/windturbine-identification/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
#  - 10s - loss: 0.7268 - acc: 0.4150 - val_loss: 0.6979 - val_acc: 0.5000
# Epoch 2/100
# ...

# %%
RESOLUTION = 14
#fpr.remove_erroneous_files(COUNTRY, RESOLUTION)
mod = fpr.train_model_res(RESOLUTION, COUNTRY, 100)
best_models.append(mod)
# Out:
# Found 45009 validated image filenames belonging to 2 classes.
# Found 15003 validated image filenames belonging to 2 classes.
# Found 15004 validated image filenames belonging to 2 classes.
# Epoch 1/100
#  - 8s - loss: 0.6967 - acc: 0.4900 - val_loss: 0.8408 - val_acc: 0.0850
# Epoch 2/100
#  - 6s - loss: 0.6552 - acc: 0.6050 - val_loss: 0.9068 - val_acc: 0.0250
# Epoch 3/100
#  - 6s - loss: 0.6324 - acc: 0.6900 - val_loss: 1.0264 - val_acc: 0.0000e+00
# Epoch 4/100
#  - 7s - loss: 0.6039 - acc: 0.7000 - val_loss: 1.0766 - val_acc: 0.0000e+00
# Epoch 5/100
#  - 6s - loss: 0.6065 - acc: 0.6850 - val_loss: 1.0787 - val_acc: 0.0050
# Epoch 6/100
#  - 6s - loss: 0.6329 - acc: 0.6250 - val_loss: 1.0155 - val_acc: 0.0150
# Epoch 7/100
#  - 6s - loss: 0.6095 - acc: 0.6350 - val_loss: 1.0098 - val_acc: 0.0000e+00
# Epoch 8/100
#  - 6s - loss: 0.6469 - acc: 0.6300 - val_loss: 0.9726 - val_acc: 0.0600
# Epoch 9/100
#  - 6s - loss: 0.6134 - acc: 0.6550 - val_loss: 0.9343 - val_acc: 0.1200
# ...

# %%
RESOLUTION = 15

#fpr.remove_erroneous_files(COUNTRY, RESOLUTION)
mod = fpr.train_model_res(RESOLUTION, COUNTRY, 100)
best_models.append(mod)
# Out:
# Found 45009 validated image filenames belonging to 2 classes.
# Found 15003 validated image filenames belonging to 2 classes.
# Found 15004 validated image filenames belonging to 2 classes.
# Epoch 1/100
#  - 8s - loss: 0.6776 - acc: 0.5700 - val_loss: 0.8090 - val_acc: 0.0950
# Epoch 2/100
#  - 7s - loss: 0.5955 - acc: 0.7750 - val_loss: 1.0335 - val_acc: 0.0000e+00
# Epoch 3/100
#  - 6s - loss: 0.5939 - acc: 0.6900 - val_loss: 1.0547 - val_acc: 0.0000e+00
# Epoch 4/100
#  - 6s - loss: 0.6354 - acc: 0.6150 - val_loss: 1.0060 - val_acc: 0.0050
# Epoch 5/100
#  - 6s - loss: 0.5983 - acc: 0.6600 - val_loss: 1.0390 - val_acc: 0.0100
# Epoch 6/100
#  - 6s - loss: 0.5402 - acc: 0.7300 - val_loss: 1.1481 - val_acc: 0.0050
# Epoch 7/100
#  - 8s - loss: 0.5776 - acc: 0.6850 - val_loss: 1.1076 - val_acc: 0.0200
# Epoch 8/100
#  - 8s - loss: 0.6109 - acc: 0.6300 - val_loss: 1.0330 - val_acc: 0.0550
# Epoch 9/100
#  - 10s - loss: 0.5364 - acc: 0.7000 - val_loss: 1.0339 - val_acc: 0.0900
# ...

# %%
RESOLUTION = 16
# fpr.remove_erroneous_files(COUNTRY, RESOLUTION)
mod = fpr.train_model_res(RESOLUTION, COUNTRY, 100)
best_models.append(mod)
# Out:
# Found 45009 validated image filenames belonging to 2 classes.
# Found 15003 validated image filenames belonging to 2 classes.
# Found 15004 validated image filenames belonging to 2 classes.
# Epoch 1/100
#  - 19s - loss: 0.6284 - acc: 0.6900 - val_loss: 1.0772 - val_acc: 0.0000e+00
# Epoch 2/100
#  - 18s - loss: 0.6310 - acc: 0.6700 - val_loss: 1.0856 - val_acc: 0.0000e+00
# Epoch 3/100
#  - 16s - loss: 0.6293 - acc: 0.6600 - val_loss: 1.0737 - val_acc: 0.0000e+00
# Epoch 4/100
#  - 20s - loss: 0.6307 - acc: 0.6550 - val_loss: 1.0480 - val_acc: 0.0000e+00
# Epoch 5/100
#  - 17s - loss: 0.6068 - acc: 0.6650 - val_loss: 1.0599 - val_acc: 0.0000e+00
# Epoch 6/100
#  - 16s - loss: 0.6355 - acc: 0.6250 - val_loss: 0.9914 - val_acc: 0.0000e+00
# Epoch 7/100
#  - 18s - loss: 0.5767 - acc: 0.6900 - val_loss: 1.0505 - val_acc: 0.0100
# Epoch 8/100
#  - 18s - loss: 0.5431 - acc: 0.7050 - val_loss: 1.0853 - val_acc: 0.0050
# Epoch 9/100
# ...

# %%
RESOLUTION = 17
# fpr.remove_erroneous_files(COUNTRY, RESOLUTION)
mod = fpr.train_model_res(RESOLUTION, COUNTRY, 100)
best_models.append(mod)
# Out:
# /home/jschmidt/.conda/envs/windturbine-identification/lib/python3.7/site-packages/keras_preprocessing/image/dataframe_iterator.py:273: UserWarning: Found 18 invalid image filename(s) in x_col="id". These filename(s) will be ignored.
#   .format(n_invalid, x_col)
# Found 44996 validated image filenames belonging to 2 classes.
# Found 14998 validated image filenames belonging to 2 classes.
# /home/jschmidt/.conda/envs/windturbine-identification/lib/python3.7/site-packages/keras_preprocessing/image/dataframe_iterator.py:273: UserWarning: Found 6 invalid image filename(s) in x_col="id". These filename(s) will be ignored.
#   .format(n_invalid, x_col)
# Found 14998 validated image filenames belonging to 2 classes.
# Epoch 1/100
#  - 16s - loss: 0.6410 - acc: 0.6650 - val_loss: 1.1008 - val_acc: 0.0000e+00
# Epoch 2/100
#  - 14s - loss: 0.6146 - acc: 0.6800 - val_loss: 1.1153 - val_acc: 0.0000e+00
# Epoch 3/100
#  - 16s - loss: 0.6202 - acc: 0.6600 - val_loss: 1.0704 - val_acc: 0.0000e+00
# ...

# %%
COUNTRY = "US"
RESOLUTION = 18
#fpr.remove_erroneous_files(COUNTRY, RESOLUTION)
mod = fpr.train_model_res(RESOLUTION, COUNTRY, 100)
best_models.append(mod)
# Out:
# /home/jschmidt/.conda/envs/windturbine-identification/lib/python3.7/site-packages/keras_preprocessing/image/dataframe_iterator.py:273: UserWarning: Found 3 invalid image filename(s) in x_col="id". These filename(s) will be ignored.
#   .format(n_invalid, x_col)
# Found 45004 validated image filenames belonging to 2 classes.
# Found 15001 validated image filenames belonging to 2 classes.
# /home/jschmidt/.conda/envs/windturbine-identification/lib/python3.7/site-packages/keras_preprocessing/image/dataframe_iterator.py:273: UserWarning: Found 4 invalid image filename(s) in x_col="id". These filename(s) will be ignored.
#   .format(n_invalid, x_col)
# Found 15004 validated image filenames belonging to 2 classes.
# Epoch 1/100
#  - 17s - loss: 0.6301 - acc: 0.6750 - val_loss: 1.2363 - val_acc: 0.0000e+00
# Epoch 2/100
#  - 11s - loss: 0.6433 - acc: 0.6400 - val_loss: 1.1313 - val_acc: 0.0000e+00
# Epoch 3/100
#  - 16s - loss: 0.5964 - acc: 0.6850 - val_loss: 1.1011 - val_acc: 0.0000e+00
# ...

# %%
COUNTRY = "US"
RESOLUTION = 19
fpr.remove_erroneous_files(COUNTRY, RESOLUTION)
mod = fpr.train_model_res(RESOLUTION, COUNTRY, 100)
best_models.append(mod)
# Out:
# /home/jschmidt/.conda/envs/windturbine-identification/lib/python3.7/site-packages/keras_preprocessing/image/dataframe_iterator.py:273: UserWarning: Found 2 invalid image filename(s) in x_col="id". These filename(s) will be ignored.
#   .format(n_invalid, x_col)
# Found 45006 validated image filenames belonging to 2 classes.
# Found 15002 validated image filenames belonging to 2 classes.
# Found 15004 validated image filenames belonging to 2 classes.
# Epoch 1/100
#  - 11s - loss: 0.7018 - acc: 0.5000 - val_loss: 0.7857 - val_acc: 0.1550
# Epoch 2/100
#  - 5s - loss: 0.6546 - acc: 0.6400 - val_loss: 0.8080 - val_acc: 0.1150
# Epoch 3/100
#  - 10s - loss: 0.6155 - acc: 0.7050 - val_loss: 0.8951 - val_acc: 0.0350
# Epoch 4/100
#  - 10s - loss: 0.5659 - acc: 0.7000 - val_loss: 0.9293 - val_acc: 0.0300
# Epoch 5/100
#  - 9s - loss: 0.5611 - acc: 0.6900 - val_loss: 0.9658 - val_acc: 0.0250
# Epoch 6/100
#  - 9s - loss: 0.5698 - acc: 0.6500 - val_loss: 0.8822 - val_acc: 0.0950
# ...

# %% [markdown]
# # Model selection

# %%
min_val_loss = min(val_loss)

i = val_loss.index(min_val_loss) + 1

best_model = "models/model-unfreezed-2-layer-2-layer-classification-6497-turbines-" + "{0:0=4d}".format(i) + "-" + "{0:.4f}".format(min_val_loss) + ".h5"

#best_model = "models/model-unfreezed-2-layer-2-layer-classification-6497-turbines-0005-0.0339.h5"

best_model

# %% [markdown]
# # Test

# %%
test_base_dir = fpr.get_param(COUNTRY, "PATH_ML_IMAGES_TURBINES_TEST")+"../"

test_model = models.load_model(best_model)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
        test_base_dir,
        target_size=(256, 256),
        batch_size=32,
        class_mode='binary')

test_loss, test_acc = test_model.evaluate_generator(test_generator, steps=32)
print('test acc:', test_acc)
print('test loss:', test_loss)
