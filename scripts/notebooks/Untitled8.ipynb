# %%
import geextract
from pprint import pprint
from datetime import datetime

# %%
geextract.ts_extract(lon=16, lat=45, sensor='LE7', start=datetime(1980, 1, 1, 0, 0), radius=500)
# Out:
# [{'B1': 274.29634945652924,
#   'B2': 553.0134629971977,
#   'B3': 360.18053316012526,
#   'B4': 4196.569924463686,
#   'B5': 2042.9500997006717,
#   'B7': 875.7659191765953,
#   'id': '1_LE07_189029_19990715'},
#  {'B1': 295.0692590355155,
#   'B2': 549.1044881199499,
#   'B3': 361.4007285643555,
#   'B4': 3906.920198583752,
#   'B5': 1969.3581593303027,
#   'B7': 847.0688320713672,
#   'id': '1_LE07_189029_19990731'},
#  {'B1': 380.1538771977025,
#   'B2': 605.9906243054498,
#   'B3': 437.46539239884436,
#   'B4': 3971.859177418789,
#   'B5': 2084.414448980546,
#   'B7': 898.6763367529566,
#   'id': '1_LE07_189029_19990816'},
#  {'B1': 317.5303530630135,
#   'B2': 516.4990120776346,
#   'B3': 371.31186097320557,
#   'B4': 3304.0060637993447,
#   'B5': 1875.586589691996,
#   'B7': 815.2509913289941,
#   'id': '1_LE07_189029_19990901'},
#  {'B1': 656.7488091299002,
#   'B2': 836.5797336696282,
#   'B3': 677.2710189353025,
#   'B4': 3584.5178271537093,
#   'B5': 2095.667349244898,
# ...
