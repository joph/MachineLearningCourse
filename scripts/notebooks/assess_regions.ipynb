# %%
cd ../..
# Out:
# /data/projects/windturbine-identification/MachineLearningCourse

# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Mar  6 12:33:58 2019

@author: jschmidt
"""

import os
from keras import models
import imp
import scripts.windturbines.functions_pattern_recognition as fpr
imp.reload(fpr)
import pandas as pd
# Out:
# Using TensorFlow backend.

# %%
# Get images from raw directory
# Convert to png in temp
# Predict
# If classified, copy

model = models.load_model('models/model-0029-0.00.h5')

# within this file, we assess new regions
COUNTRY = "CN"

raw_dir = fpr.get_param(COUNTRY, "PATH_RAW_IMAGES_ASSESSMENT")
temp_dir = fpr.get_param(COUNTRY, "PATH_TEMP")

dirs = [os.path.basename(os.path.normpath(f.path)) for f in os.scandir(raw_dir) if f.is_dir() ]    

allResults = []
# Out:
# WARNING:tensorflow:From /home/jschmidt/.conda/envs/windturbine-identification/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/jschmidt/.conda/envs/windturbine-identification/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
i=0
found_turbines = fpr.assess_windparks_country(raw_dir, dirs[i:(i+1)],
                                              temp_dir, model)


assessment_out_file = fpr.get_param(COUNTRY, "PATH_RAW_IMAGES_ASSESSMENT") + "/assessment.csv" 

p = pd.DataFrame(found_turbines)

p.to_csv(assessment_out_file)
# Out:
# Currently assessing Abag Banner Huiteng Liang Phase 1

# %%
# p = pd.read_csv(assessment_out_file)

# %%
len(dirs)
# Out:
# 835

# %%
for i in range(1,len(dirs)):
    found_turbines = fpr.assess_windparks_country(raw_dir, dirs[i:(i+1)],
                                              temp_dir, model)
    p1 = pd.DataFrame(found_turbines)

    p = p.append(p1)
    
    p.to_csv(assessment_out_file)
# Out:
# Currently assessing Anhui Laian Baoshan Wind
# Currently assessing Anhui Laian Longtougang Wind
# Currently assessing Anhui Laian Longwosi Wind
# Currently assessing Anning River Canyon (Phase 1) Dechang County
# Currently assessing Ansai Wangjiawan
# Currently assessing Baibuluo
# Currently assessing Baishi
# Currently assessing Baiyun Ebo Inner Mongolia Luneng Phase 2
# Currently assessing Baiyunebo
# Currently assessing Banmei
# Currently assessing Bayannaoer Chuanjingsumu 3 Wind
# Currently assessing Bayannaoer Chuanjingsumu Wind
# Currently assessing Bayannur Wulanyiligeng Wind Farm
# Currently assessing Bayanur Wuliji Wind Phase 2
# Currently assessing Bayinhanggai
# Currently assessing Bayinxile
# Currently assessing Beijing Energy Huitengxile Wind
# Currently assessing Beijing Guanting Wind Phase 2
# Currently assessing Beijing Yanqing Low Windspeed Pilot
# Currently assessing Beizhen Jiazishan Wind
# Currently assessing Beizhen Yangjiadian Wind
# ...
